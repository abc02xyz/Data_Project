# %%
import requests, json, os, sys, time, re, math,csv
from datetime import datetime
import pandas as pd

# %%
def show_work_status(singleCount, totalCount, currentCount=0):
    currentCount += singleCount
    percentage = 100.0 * currentCount / totalCount
    status =  '>' * int(percentage)  + ' ' * (100 - int(percentage))
    sys.stdout.write('\r[{0}] {1:.2f}% '.format(status, percentage))
    sys.stdout.flush()
    if percentage >= 100:
        print('\n')


def split_list(lst_long,n):
    lst_splitted = []
    if len(lst_long) % n == 0:
        totalBatches = len(lst_long) / n
    else:
        totalBatches = len(lst_long) / n + 1
    for i in range(int(totalBatches)):
        lst_short = lst_long[i*n:(i+1)*n]
        lst_splitted.append(lst_short)
    return lst_splitted

# %% [markdown]
# ## Get  game data and detail

# %%
url = 'https://api.steampowered.com/ISteamApps/GetAppList/v2/'
r = requests.get(url)
dic_app_list = r.json()
lst_app_id = [i.get('appid') for i in dic_app_list.get('applist').get('apps')]
print('Total apps:', len(lst_app_id))
# Out:
# Total apps: 93828

# %%
dic_app_list
# Out:
# {'applist': {'apps': [{'appid': 216938,
#     'name': 'Pieterw test app76 ( 216938 )'},
#    {'appid': 660010, 'name': 'test2'},
#    {'appid': 660130, 'name': 'test3'},
#    {'appid': 1269470, 'name': 'Zakk Hazard The Deadly Spawn Soundtrack'},
#    {'appid': 1269490,
#     'name': 'Sweet Story Fallen Angel - 18+ Adult Only Content'},
#    {'appid': 1269500, 'name': 'Crowalt: Traces of the Lost Colony'},
#    {'appid': 1269510, 'name': 'UNDERZONE'},
#    {'appid': 1269540, 'name': 'Slash Roll'},
#    {'appid': 1269560, 'name': 'Square Fast'},
#    {'appid': 1269590, 'name': 'Get-A-Grip Chip'},
#    {'appid': 1269610, 'name': 'Aquarius Demo'},
#    {'appid': 1269630, 'name': 'Western Sigil'},
#    {'appid': 1269650, 'name': 'Amendium'},
#    {'appid': 1269670, 'name': 'Quench Demo'},
#    {'appid': 1269680, 'name': 'Backworlds Demo'},
#    {'appid': 1269700, 'name': '4 Minutes to the Apocalypse'},
#    {'appid': 1269710, 'name': 'Kainga'},
#    {'appid': 1269730, 'name': 'Legacies'},
#    {'appid': 1269742, 'name': 'Adventure Field™ 3 Super Potion x 50'},
#    {'appid': 1269743, 'name': 'Adventure Field™ 3 Super Potion x 100'},
#    {'appid': 1269745, 'name': 'Adventure Field™ 3 10,000 Golds'},
#    {'appid': 1269746, 'name': 'Adventure Field™ 3 100,000 Golds'},
#    {'appid': 1269748, 'name': 'Adventure Field™ 3 Shiny Charm'},
#    {'appid': 1269755, 'name': 'Adventure Field™ 3 Rare Potion x 5'},
#    {'appid': 1269810, 'name': 'The Curse of Kubel'},
#    {'appid': 1269820, 'name': "Kozue's Strange Journey"},
#    {'appid': 1268970,
#     'name': 'Soul at Stake - "Drowning Flower" The Drowner\'s Outfit'},
#    {'appid': 1268980, 'name': 'holedown soundtrack'},
#    {'appid': 1269000, 'name': 'Operencia: The Stolen Sun Demo'},
#    {'appid': 1269020, 'name': 'No Plan B'},
#    {'appid': 1269050, 'name': '告死天使的审判'},
#    {'appid': 1269120, 'name': 'Freakshow'},
#    {'appid': 1269160, 'name': 'Hazel Sky Demo'},
#    {'appid': 1269170, 'name': 'Recompile Demo'},
#    {'appid': 1269180,
#     'name': "Fatal Evidence: The Missing Collector's Edition"},
#    {'appid': 1269210, 'name': 'Liberated Demo'},
#    {'appid': 1269220, 'name': 'Harem Girl: Nikki - Expanded Content'},
#    {'appid': 1269221, 'name': 'Harem Girl: Nikki - Solve It Mode'},
#    {'appid': 1269240, 'name': 'Damn Dolls'},
#    {'appid': 1269250, 'name': 'War Smith'},
#    {'appid': 1269330, 'name': 'Batbarian Demo'},
#    {'appid': 1269340, 'name': 'Floody Demo'},
#    {'appid': 1269350, 'name': 'Neuronaut'},
#    {'appid': 1269360, 'name': 'Freedom Finger Soundtrack'},
#    {'appid': 1269370, 'name': '171'},
#    {'appid': 1269380, 'name': 'Divisadero Demo'},
#    {'appid': 1269400, 'name': 'The 100-Player Twitch Chat Party Pack'},
#    {'appid': 1269430, 'name': 'Duster Demo'},
#    {'appid': 1269440, 'name': 'Hentai Splash - Patch 18+'},
#    {'appid': 1269450, 'name': 'Goofy Golf Remastered Steam Edition'},
#    {'appid': 1268520,
#     'name': 'Fantasy Grounds - Devin Night TP127: Fantastic Foes'},
#    {'appid': 1268580,
#     'name': 'Fantasy Grounds - Devin Night TP126: Total Chaos'},
#    {'appid': 1268610, 'name': 'Starport Delta Soundtrack'},
#    {'appid': 1268620, 'name': 'QUIZ PRO! - General Knowledge - HISTORY'},
#    {'appid': 1268710, 'name': 'Skitt'},
#    {'appid': 1268720, 'name': 'EleMetals: Death Metal Death Match! Demo'},
#    {'appid': 1268730, 'name': 'Impulse Control'},
#    {'appid': 1268740, 'name': 'We should talk. Demo'},
#    {'appid': 1268760, 'name': 'Embr Alpha Demo'},
#    {'appid': 1268800, 'name': 'Divisadero'},
#    {'appid': 1268820,
#     'name': 'Torque Drift - Vaughn Gittin Jr 1969 Mustang Driver Car'},
#    {'appid': 1268821,
#     'name': 'Torque Drift - Vaughn Gittin Jr Ford Focus Driver Car'},
#    {'appid': 1268830, 'name': 'Flappy Hypership Out of Control'},
#    {'appid': 1268840, 'name': 'Project Toon Tanks'},
#    {'appid': 1268850, 'name': 'Hentai Furry - Artbook 18+'},
#    {'appid': 1268860, 'name': 'Raindrops'},
#    {'appid': 1268880, 'name': '方圈 Square Circle'},
#    {'appid': 1268890, 'name': 'Mystic Pillars Demo'},
#    {'appid': 1268930, 'name': 'Hundred Days Demo'},
#    {'appid': 1268940, 'name': 'Wish - Innocent'},
#    {'appid': 1268950, 'name': 'Metal Unit Demo'},
#    {'appid': 1268960, 'name': 'pureya'},
#    {'appid': 1268010, 'name': 'Uniform Girl - Patch'},
#    {'appid': 1268040, 'name': 'Fluid Engine PC Live Wallpaper'},
#    {'appid': 1268060, 'name': 'Ultimate Dinos World'},
#    {'appid': 1268080, 'name': 'When The Past Was Around Demo'},
#    {'appid': 1268090, 'name': 'A Space For The Unbound Demo'},
#    {'appid': 1268100, 'name': 'War Islands'},
#    {'appid': 1268120, 'name': 'Star Conflict: Scylla'},
#    {'appid': 1268130, 'name': '赫炎的印加诺克 Original Soundtrack'},
#    {'appid': 1268140, 'name': '蘭島物語：少女的約定 復刻版'},
#    {'appid': 1268150, 'name': 'Low Poly Forces'},
#    {'appid': 1268160, 'name': 'Seven Horns From Tilt'},
#    {'appid': 1268190, 'name': 'Naked Puzzle: Girls'},
#    {'appid': 1268200, 'name': 'Espresso For The Demon'},
#    {'appid': 1268210, 'name': '赫炎的印加诺克 Digital Visual Fanbook'},
#    {'appid': 1268220, 'name': 'Rising Hell Demo'},
#    {'appid': 1268280, 'name': 'Knockdown the Ball Twice'},
#    {'appid': 1268300, 'name': 'Lovely Girl Patch'},
#    {'appid': 1268360, 'name': 'Wasted Worlds'},
#    {'appid': 1268380,
#     'name': 'Endless RPG: Random Dungeon Map Generator for D&D 5e'},
#    {'appid': 1268390, 'name': 'Welcome To... Chichester OVN 3 : The Script'},
#    {'appid': 1268400, 'name': 'Pinball Lockdown'},
#    {'appid': 1268410, 'name': 'Hentai Demon'},
#    {'appid': 1268440, 'name': 'Pushy and Pully in Blockland Demo'},
#    {'appid': 1268450, 'name': 'Battlefleet Gothic: Armada 2 Soundtrack'},
#    {'appid': 1268460,
#     'name': 'Space Hulk: Deathwing - Enhanced Edition Soundtrack'},
#    {'appid': 1268470,
#     'name': 'Fantasy Grounds - Devin Night TP128: Fiendish Foes'},
#    {'appid': 1268480, 'name': 'Mighty Fight Federation Demo'},
#    {'appid': 1267550,
#     'name': 'Our Journeys 3 ~ A Collection of Visual Novels'},
#    {'appid': 1267570, 'name': 'Vectronom Demo'},
#    {'appid': 1267590,
#     'name': 'Beat Saber - Sid Tipton & Timbaland - Has A Meaning'},
#    {'appid': 1267591,
#     'name': 'Beat Saber - Kaydence & Timbaland - Dumb Thingz'},
#    {'appid': 1267592, 'name': 'Beat Saber - Wavezswavesz - While We’re Young'},
#    {'appid': 1267593,
#     'name': 'Beat Saber - Nash Overstreet, Karra & Common Strangers - What I Like'},
#    {'appid': 1267594,
#     'name': 'Beat Saber - Bruno Martini & Timbaland - Famous ft. Jake Davis'},
#    {'appid': 1267600, 'name': 'Gray Zone Soundtrack'},
#    {'appid': 1267610, 'name': 'Birth ME Code Demo'},
#    {'appid': 1267670, 'name': 'Heartless reseller is Roguelike'},
#    {'appid': 1267710, 'name': 'Ancient charm 18-No'},
#    {'appid': 1267730, 'name': 'Ironsight - Chrome K2C Pack'},
#    {'appid': 1267770, 'name': 'Linda & Joan Prologue: “Four Months Earlier”'},
#    {'appid': 1267780,
#     'name': 'Aeolis Tournament - KickStarter Exclusive Item'},
#    {'appid': 1267790, 'name': '维度访问Resident of Dimension'},
#    {'appid': 1267800, 'name': 'Harem Girl: Alicia - Expanded Content'},
#    {'appid': 1267801, 'name': 'Harem Girl: Alicia - Solve It Mode'},
#    {'appid': 1267810, 'name': 'Gutwhale'},
#    {'appid': 1267830, 'name': 'Smartphone Tycoon - Lite'},
#    {'appid': 1267860, 'name': 'Hinterhalt 3'},
#    {'appid': 1267870, 'name': 'Xenogunner'},
#    {'appid': 1267920, 'name': 'Stealth Master'},
#    {'appid': 1267950, 'name': 'Cosmic Flow: A Relaxing VR Experience'},
#    {'appid': 1267960, 'name': 'FotoMuseo 3D'},
#    {'appid': 1267990, 'name': 'SYB_DLC3.0'},
#    {'appid': 1267270, 'name': 'Yumeutsutsu Re:Idol'},
#    {'appid': 1267300, 'name': 'Big cities'},
#    {'appid': 1267330, 'name': 'Group Project Simulator'},
#    {'appid': 1267340, 'name': 'RPG Maker MV - Heroine Character Generator 6'},
#    {'appid': 1267341, 'name': 'RPG Maker MV - Essential Fantasy Music Pack'},
#    {'appid': 1267342,
#     'name': 'RPG Maker MV - Dark Horror Cinematic Music Vol.1'},
#    {'appid': 1267343,
#     'name': 'RPG Maker MV - Dark Horror ME Perfect Collection'},
#    {'appid': 1267344, 'name': 'RPG Maker MV - Modern + Study Time MV'},
#    {'appid': 1267360,
#     'name': 'RPG Maker VX Ace - Essential Fantasy Music Pack'},
#    {'appid': 1267361,
#     'name': 'RPG Maker VX Ace - Dark Horror Cinematic Music Vol.1'},
#    {'appid': 1267362,
#     'name': 'RPG Maker VX Ace - Dark Horror ME Perfect Collection'},
#    {'appid': 1267363, 'name': 'RPG Maker VX Ace - Modern + Study Time VX Ace'},
#    {'appid': 1267380,
#     'name': 'Visual Novel Maker - Essential Fantasy Music Pack'},
#    {'appid': 1267381,
#     'name': 'Visual Novel Maker - Dark Horror Cinematic Music Vol.1'},
#    {'appid': 1267382,
#     'name': 'Visual Novel Maker - Dark Horror ME Perfect Collection'},
#    {'appid': 1267410, 'name': 'Kurogane of the sky'},
#    {'appid': 1267420, 'name': 'Sons of Ra Demo'},
#    {'appid': 1267450, 'name': 'Sunrise 7 Demo'},
#    {'appid': 1267460, 'name': 'Sunrise 7 Soundtrack'},
#    {'appid': 1267520, 'name': 'Filament Demo'},
#    {'appid': 1267530, 'name': 'Weaving Tides: Prologue'},
#    {'appid': 1267020, 'name': 'Clicker Legends'},
#    {'appid': 1267030,
#     'name': 'Fantasy Grounds - Devin Night TP129: Heroic Characters 25'},
#    {'appid': 1267050, 'name': 'BUKKAKE'},
#    {'appid': 1267060, 'name': 'WoMen in Science Soundtrack'},
#    {'appid': 1267080, 'name': 'Stanford Polygon Library (*.ply)'},
#    {'appid': 1267090, 'name': '3DStudio Max (*.3ds, *.ase)'},
#    {'appid': 1267091, 'name': 'Cinema4D (*.c4d)'},
#    {'appid': 1267092, 'name': 'Virtual Reality Modeling Language (*.wrl)'},
#    {'appid': 1267093, 'name': 'Autodesk (*.fbx)'},
#    {'appid': 1267094, 'name': 'Collada (*.dae)'},
#    {'appid': 1267095, 'name': 'Blender (*.blend)'},
#    {'appid': 1267097, 'name': 'Milkshape 3D (*.ms3d)'},
#    {'appid': 1267098, 'name': 'Industry Foundation Classes (*.ifc)'},
#    {'appid': 1267099, 'name': 'LightWave (*.lwo, *.lws)'},
#    {'appid': 1267100, 'name': 'AC3D (*.ac)'},
#    {'appid': 1267101, 'name': 'Modo (*.lxo)'},
#    {'appid': 1267102, 'name': 'XGL (*.xgl, *.zgl)'},
#    {'appid': 1267103, 'name': 'GL Transmission Format (*.gltf, *,glb)'},
#    {'appid': 1267104, 'name': 'DirectX (*.x)'},
#    {'appid': 1267105, 'name': 'Additive Manufacturing File (*.amf)'},
#    {'appid': 1267106, 'name': 'Extensible 3D (*.x3d)'},
#    {'appid': 1267140, 'name': 'Autumn'},
#    {'appid': 1267150, 'name': 'We Are The Caretakers Demo'},
#    {'appid': 1267190, 'name': 'Umurangi Generation Demo'},
#    {'appid': 1267200, 'name': 'Hectic Demo'},
#    {'appid': 1267210, 'name': 'Together in Battle'},
#    {'appid': 1267230, 'name': 'Labyrinth: The Exit Is Closer'},
#    {'appid': 1267260, 'name': 'Yumeutsutsu Re:After'},
#    {'appid': 1266710,
#     'name': 'Firestone Idle RPG - Orc Thief, The gold Hunter  - Avatar'},
#    {'appid': 1266711,
#     'name': 'Firestone Idle RPG - Assassin, The silent danger  - Avatar'},
#    {'appid': 1266712,
#     'name': 'Firestone Idle RPG - Troll Archer, The Legionnaire of Mayhem  - Avatar'},
#    {'appid': 1266713,
#     'name': 'Firestone Idle RPG - Bandit, The Ex Crusader  - Avatar'},
#    {'appid': 1266714,
#     'name': 'Firestone Idle RPG - Troll Warrior, The Blade of Terror  - Avatar'},
#    {'appid': 1266715,
#     'name': 'Firestone Idle RPG - Mercenary, The Soldier of Destiny  - Avatar'},
#    {'appid': 1266716,
#     'name': 'Firestone Idle RPG - Orc Warrior, The Champion of Thal Badur  - Avatar'},
#    {'appid': 1266717,
#     'name': 'Firestone Idle RPG - Skeleton Warrior, The exile of the world  - Avatar'},
#    {'appid': 1266718,
#     'name': 'Firestone Idle RPG - Undead Warrior, The Hero of the Underworld  - Avatar'},
#    {'appid': 1266719,
#     'name': 'Firestone Idle RPG - Skeleton Archer, The Terror of Paladins  - Avatar'},
#    {'appid': 1266740,
#     'name': 'Vampire: The Masquerade - Coteries of New York Soundtrack'},
#    {'appid': 1266750,
#     'name': 'Vampire: The Masquerade - Coteries of New York Artbook'},
#    {'appid': 1266760, 'name': 'Battlefleet Gothic: Armada Soundtrack'},
#    {'appid': 1266770, 'name': 'Plebby Quest: The Crusades OST'},
#    {'appid': 1266890, 'name': 'Tactical Troops: Anthracite Shift'},
#    {'appid': 1266940,
#     'name': 'Fantasy Grounds - Starfinder RPG - Attack of the Swarm AP 5: Hive of Minds'},
#    {'appid': 1266230, 'name': 'In Other Waters Soundtrack'},
#    {'appid': 1266250, 'name': 'Neon City Riders Soundtrack'},
#    {'appid': 1266260, 'name': 'Tribble Troubles'},
#    {'appid': 1266310, 'name': 'PAGO FOREST : TOWER DEFENSE'},
#    {'appid': 1266380, 'name': 'Super No Crying in Baseball'},
#    {'appid': 1266400, 'name': 'Hentai Harem'},
#    {'appid': 1266450, 'name': 'Match Number Panels'},
#    {'appid': 1266470, 'name': 'Real VR Fishing'},
#    {'appid': 1266480, 'name': 'MiNNaDe Counter Fight'},
#    {'appid': 1266500,
#     'name': 'LET IT DIE -(6 Mil Downloads)100 Death Metals-'},
#    {'appid': 1266501, 'name': 'LET IT DIE -(6 Mil Downloads)Special pack-'},
#    {'appid': 1266502, 'name': 'LET IT DIE -(Special)10 Death Metals- 017'},
#    {'appid': 1266503, 'name': 'LET IT DIE -(Special)50 Death Metals- 014'},
#    {'appid': 1266510,
#     'name': 'Soul at Stake - "Martial Spirit" Daniel\'s Outfit'},
#    {'appid': 1266550, 'name': 'Cannibal Cuisine Demo'},
#    {'appid': 1266580, 'name': 'eden* Soundtrack'},
#    {'appid': 1266610, 'name': 'ZOE'},
#    {'appid': 1266620, 'name': 'ZOE Demo'},
#    {'appid': 1266650, 'name': 'Cyber Driver VR'},
#    {'appid': 1266660, 'name': 'Kongfusion Demo'},
#    {'appid': 1266680, 'name': 'Strobophagia | Rave Horror'},
#    {'appid': 1265840, 'name': '198X Soundtrack'},
#    {'appid': 1265850, 'name': 'Sokpop S07: Chatventures'},
#    {'appid': 1265870, 'name': 'Cave Digger 2D'},
#    {'appid': 1265880, 'name': 'Wunderling Demo'},
#    {'appid': 1265960, 'name': 'Kongfusion'},
#    {'appid': 1265970, 'name': "Dark City: Dublin Collector's Edition"},
#    {'appid': 1265990, 'name': 'QUIZ PRO! - General Knowledge'},
#    {'appid': 1266070, 'name': 'Smashing Healthy VR'},
#    {'appid': 1266130, 'name': 'One Step From Eden Soundtrack'},
#    {'appid': 1266140, 'name': 'Succubus Domination'},
#    {'appid': 1266210, 'name': 'Through the Nightmares'},
#    {'appid': 1265390, 'name': '艾鲁大陆'},
#    {'appid': 1265400, 'name': 'KungFu Kickball Demo'},
#    {'appid': 1265410, 'name': 'Computer Physics Simulators 2020'},
#    {'appid': 1265440, 'name': 'Fire Guild'},
#    {'appid': 1265450, 'name': 'DIMENSION REIGN Soundtrack'},
#    {'appid': 1265490, 'name': 'Super Squash Demo'},
#    {'appid': 1265500, 'name': 'Mystiqa'},
#    {'appid': 1265560, 'name': 'Granado Espada Ailis region OST collection'},
#    {'appid': 1265580, 'name': 'Miden Tower'},
#    {'appid': 1265600, 'name': 'ReflexShot - 扩展地图'},
#    {'appid': 1265610, 'name': 'Dandy Dungeon - Legend of Brave Yamada - Demo'},
#    {'appid': 1265620, 'name': 'Car Mechanic Simulator 2018 - Chrysler DLC'},
#    {'appid': 1265690, 'name': 'Horse Riding Deluxe 2'},
#    {'appid': 1265700, 'name': 'BH Trials Soundtrack'},
#    {'appid': 1265710,
#     'name': 'Firestone Idle RPG - Goblin: The Little Monster'},
#    {'appid': 1265770, 'name': 'Tunnel Bird'},
#    {'appid': 1265810, 'name': 'Spacen: The Beginning'},
#    {'appid': 1265820, 'name': 'Fights in Tight Spaces'},
#    {'appid': 1264940, 'name': 'Two Weeks Game'},
#    {'appid': 1264950, 'name': 'Super Space Slayer 2 Demo'},
#    {'appid': 1264970, 'name': 'The Conquest of Go'},
#    {'appid': 1264980, 'name': '99 Anime Girls'},
#    {'appid': 1264990, 'name': 'BallClimbing'},
#    {'appid': 1265000, 'name': 'Coronavirus Attack'},
#    {'appid': 1265030, 'name': 'Moorhuhn Kart'},
#    {'appid': 1265060, 'name': 'Tactical Nexus Chapter 4 -Tactical Star-'},
#    {'appid': 1265070, 'name': 'Escape From Violet Institute'},
#    {'appid': 1265080, 'name': '溜冰的猪少'},
#    {'appid': 1265100, 'name': 'Hentai Two Girls Arts'},
#    {'appid': 1265120, 'name': 'Freddy Spaghetti'},
#    {'appid': 1265130, 'name': 'iMemo'},
#    {'appid': 1265200, 'name': 'Escort Alia'},
#    {'appid': 1265240, 'name': 'Uniform Girl'},
#    {'appid': 1265250,
#     'name': 'Fantasy Grounds - D&D Classics: S4 The Lost Caverns of Tsojcanth (1E)'},
#    {'appid': 1265270, 'name': 'Madness Fantasy'},
#    {'appid': 1265280, 'name': 'The 99 - Action-Quiz'},
#    {'appid': 1265330,
#     'name': 'Fantasy Grounds - D&D S4 The Lost Caverns of Tsojcanth'},
#    {'appid': 1265350, 'name': 'When I Was Young Soundtrack'},
#    {'appid': 1265360, 'name': '3D Hentai Blackjack'},
#    {'appid': 1264470, 'name': '3dRudder Driver for SteamVR'},
#    {'appid': 1264500, 'name': 'Soldier Matt Sowards'},
#    {'appid': 1264510, 'name': 'Get Out...'},
#    {'appid': 1264540, 'name': 'The Monster Breeder Demo'},
#    {'appid': 1264610, 'name': '驱逐'},
#    {'appid': 1264620, 'name': 'Lucen'},
#    {'appid': 1264630, 'name': 'CHAR01 VR'},
#    {'appid': 1264640, 'name': 'Wallpaper Master'},
#    {'appid': 1264670, 'name': '紫塞秋风 The Wind Road'},
#    {'appid': 1264690, 'name': 'Necrolepsy Demo'},
#    {'appid': 1264700, 'name': 'Premium Season Pass'},
#    {'appid': 1264710, 'name': 'Love & Sex: Second Base'},
#    {'appid': 1264730, 'name': 'Total Arcade Racing'},
#    {'appid': 1264740, 'name': 'Lucid Dream'},
#    {'appid': 1264760, 'name': 'Saturn Quest: Shadow of Planetus'},
#    {'appid': 1264770, 'name': 'Coronavirus Evolution'},
#    {'appid': 1264780, 'name': 'The Mystery Of Woolley Mountain  - Art Book'},
#    {'appid': 1264790, 'name': 'Destiny of the World'},
#    {'appid': 1264800, 'name': 'Radical Solitaire'},
#    {'appid': 1264810, 'name': 'Seals of the Bygone Soundtrack'},
#    {'appid': 1264820, 'name': 'Jade Cicada'},
#    {'appid': 1264830, 'name': 'The Cold War Era 2'},
#    {'appid': 1264840, 'name': 'Fantasy Story'},
#    {'appid': 1264890, 'name': 'Space Force'},
#    {'appid': 1264900, 'name': 'Simple Farm'},
#    {'appid': 1264920, 'name': 'Endgame: Road To Salvation'},
#    {'appid': 1264930, 'name': 'King of the Streets'},
#    {'appid': 1237310, 'name': 'Rocket Shipment'},
#    {'appid': 1237330, 'name': 'GraFi Valentine'},
#    {'appid': 1237340, 'name': 'Shisensho Solitaire Demo'},
#    {'appid': 1237360, 'name': 'Radical Rabbit Stew Demo'},
#    {'appid': 1237410, 'name': 'VE GSIM Overhead Crane Simulator'},
#    {'appid': 1237450,
#     'name': '30 Days to survive - wallpapers for your desktop. Bundle 1'},
#    {'appid': 1237460, 'name': 'Phoenix Strike'},
#    {'appid': 1237470, 'name': 'Glyph - Dustland Challenges'},
#    {'appid': 1237480, 'name': 'Isle Of Spirits'},
#    {'appid': 1237490, 'name': 'Redneck Ed: Astro Monsters Show'},
#    {'appid': 1237530, 'name': 'Kinky Fight Club'},
#    {'appid': 1237540, 'name': 'Ultimate MMA'},
#    {'appid': 1237550, 'name': 'Great Alhcemist'},
#    {'appid': 1237560, 'name': 'Hot steel'},
#    {'appid': 1237590, 'name': 'Attack of the alien thingies from lava!'},
#    {'appid': 1237600, 'name': 'BEAUTIFUL DESOLATION Supporters Pack'},
#    {'appid': 1237630, 'name': 'DAEMON X MACHINA - Prototype Arsenal Set'},
#    {'appid': 1237650, 'name': 'Monument Soundtrack'},
#    {'appid': 1237660, 'name': '终回〇Murder Reservation'},
#    {'appid': 1237670, 'name': 'Anti Air'},
#    {'appid': 1237700, 'name': 'Building The Universe'},
#    {'appid': 1237720, 'name': 'Coloring Pixels - Realistic Pack'},
#    {'appid': 1237721, 'name': 'Coloring Pixels - Music Pack'},
#    {'appid': 1236790, 'name': 'The Pedestrian Soundtrack'},
#    {'appid': 1236820, 'name': 'Where The Clouds End'},
#    {'appid': 1236860, 'name': 'Edge of Reality'},
#    {'appid': 1236880, 'name': 'Survival Africa'},
#    {'appid': 1236920, 'name': 'SPACE EXODUS'},
#    {'appid': 1236930, 'name': 'Outliver: Tribulation'},
#    {'appid': 1236940, 'name': '10 Second Shuriken Demo'},
#    {'appid': 1236960,
#     'name': "Living Legends: The Crystal Tear Collector's Edition"},
#    {'appid': 1236990, 'name': 'Boris and the Dark Survival'},
#    {'appid': 1237020, 'name': 'Eliza Original Soundtrack'},
#    {'appid': 1237030, 'name': 'Speaking Simulator Soundtrack'},
#    {'appid': 1237040, 'name': 'Alpha Hole Prison'},
#    {'appid': 1237050, 'name': 'TheWandererVR'},
#    {'appid': 1237060, 'name': 'Wise Escape From Prison (현명한 감옥 탈출기)'},
#    {'appid': 1237080, 'name': 'Comic Book Tycoon'},
#    {'appid': 1237090, 'name': 'Bounty For Sharks'},
#    {'appid': 1237110, 'name': "Me and (My) Cat's Castle"},
#    {'appid': 1237120, 'name': "Me and (My) Cat's Castle X"},
#    {'appid': 1237160, 'name': 'Minit Soundtrack'},
#    {'appid': 1237190, 'name': 'Orbis Fugae'},
#    {'appid': 1237200, 'name': 'Star Conflict: Papa Crab'},
#    {'appid': 1237210, 'name': 'EMPTY'},
#    {'appid': 1237220, 'name': 'Hentai Thigh'},
#    {'appid': 1237230, 'name': '30 days to survive Soundtrack'},
#    {'appid': 1237240, 'name': 'Crypt Of Shadows'},
#    {'appid': 1237270, 'name': 'Blood Branched Sakura'},
#    {'appid': 1236320, 'name': 'Phalanx of Resistance'},
#    {'appid': 1236330, 'name': 'Car Tuner 2020'},
#    {'appid': 1236350, 'name': 'Mission:In Boxes'},
#    {'appid': 1236390, 'name': 'Epic Chess'},
#    {'appid': 1236400, 'name': 'Hentai hentai'},
#    {'appid': 1236450, 'name': "Incredible Dracula: Ocean's Call"},
#    {'appid': 1236460, 'name': 'Box Kid Adventures Demo'},
#    {'appid': 1236480, 'name': 'King of Volleyball'},
#    {'appid': 1236500, 'name': 'TEKKEN 7 - DLC14: Fahkumram'},
#    {'appid': 1236501, 'name': 'TEKKEN 7 - DLC15: CAVE OF ENLIGHTENMENT'},
#    {'appid': 1236520, 'name': 'Null & Peta: Audio Commentary'},
#    {'appid': 1236530, 'name': 'Starters Orders Classic Horse Racing'},
#    {'appid': 1236550, 'name': 'Abandon Ship - Art Book'},
#    {'appid': 1236560, 'name': 'The Dawn of Art'},
#    {'appid': 1236580, 'name': 'Tritium'},
#    {'appid': 1236610, 'name': 'Woodle Tree 2: Deluxe+ Soundtrack'},
#    {'appid': 1236630, 'name': 'UEDI: Shadow of the Citadel'},
#    {'appid': 1236640,
#     'name': 'Warhammer 40,000: Mechanicus - Complete Original Soundtrack'},
#    {'appid': 1236650, 'name': 'American Truck Simulator - Operation BORK'},
#    {'appid': 1236660,
#     'name': 'OMSI 2 Add-on Downloadpack Vol. 9 – KI-Luxusautos'},
#    {'appid': 1236760, 'name': 'Rule the Rail!'},
#    {'appid': 1235850, 'name': '愛情限時批 Demo'},
#    {'appid': 1235950, 'name': 'Introvert'},
#    {'appid': 1235960, 'name': 'Beerman Demo'},
#    {'appid': 1235980, 'name': 'Nice Try!'},
#    {'appid': 1235990, 'name': 'Fastidious'},
#    {'appid': 1236000, 'name': 'Armoured Onslaught'},
#    {'appid': 1236010, 'name': 'Treis Zoes light.in.mist Soundtrack'},
#    {'appid': 1236020, 'name': 'Dig Mania'},
#    {'appid': 1236050, 'name': 'Genius!'},
#    {'appid': 1236060, 'name': 'Don Juan Of The Galaxy'},
#    {'appid': 1236070, 'name': 'Mission Zigloton'},
#    {'appid': 1236100, 'name': 'Of Evil and Darkness'},
#    {'appid': 1236140, 'name': 'Hentai Girl Seek'},
#    {'appid': 1236180, 'name': 'The Whipper'},
#    {'appid': 1236190, 'name': 'Korpus: Buried over the Black Soil'},
#    {'appid': 1236210, 'name': 'Overpass Soundtrack'},
#    {'appid': 1236230, 'name': 'Null & Peta - Anime Soundtrack'},
#    {'appid': 1236250, 'name': 'Cult达人极限攀岩'},
#    {'appid': 1236260, 'name': 'Holy Knight Luviria Original Soundtrack'},
#    {'appid': 1236270, 'name': 'SkyJump'},
#    {'appid': 1236280, 'name': "loong's utilities Playnite"},
#    {'appid': 1235650, 'name': 'Back To Hell Demo'},
#    {'appid': 1235660, 'name': 'Flatspace (The Official Soundtrack)'},
#    {'appid': 1235670, 'name': 'Flatspace II (The Official Soundtrack)'},
#    {'appid': 1235770, 'name': 'Volleyballed'},
#    {'appid': 1235790, 'name': 'dancing chair'},
#    {'appid': 1235810, 'name': 'Retro'},
#    {'appid': 1235830, 'name': 'Dark Water'},
#    {'appid': 1235130, 'name': 'Roboshark Rampage'},
#    {'appid': 1235160, 'name': 'Boom Stick'},
#    {'appid': 1235220, 'name': 'There a no Armadillos in this game'},
#    {'appid': 1235260, 'name': 'Steam Controller Configs - Secure Desktop'},
#    {'appid': 1235280, 'name': 'Brawlhalla - Winter Championship 2020 Pack'},
#    {'appid': 1235310, 'name': 'Exhaust'},
#    {'appid': 1235320, 'name': 'Reach Demo'},
#    {'appid': 1235330, 'name': 'White Wings ホワイトウィングス Theme ED Song 逢瀬アキラ.ver'},
#    {'appid': 1235340, 'name': 'Turbo Boom!'},
#    {'appid': 1235370, 'name': 'Gamedev Beatdown Demo'},
#    {'appid': 1235380, 'name': '恆夜世界的魔法少女 Demo'},
#    {'appid': 1235400, 'name': 'CATharsis'},
#    {'appid': 1235410, 'name': 'Gamepad Massage - source code'},
#    {'appid': 1235430, 'name': 'CUBeKA'},
#    {'appid': 1235440, 'name': '長星 Long Star'},
#    {'appid': 1235460, 'name': 'Angry Bunny 2: Lost hole'},
#    {'appid': 1235480, 'name': 'Abst Clicker Farm'},
#    {'appid': 1235520, 'name': 'HENTAI DANCE'},
#    {'appid': 1235530, 'name': 'Yag - Cartoon Content'},
#    {'appid': 1235570, 'name': 'Indian Army - Mission POK '},
#    {'appid': 1235580, 'name': 'Greed Demo'},
#    {'appid': 1235600, 'name': 'Weapons of Larth'},
#    {'appid': 1234580, 'name': 'fullybroKEN - A Unique Post-Apocalyptic RPG'},
#    {'appid': 1234590, 'name': 'Class Kingdom'},
#    {'appid': 1234600, 'name': 'Hollow Remnant'},
#    {'appid': 1234610, 'name': 'BELOW Vol. 3 - Soundtrack'},
#    {'appid': 1234620, 'name': 'Tinker Racers'},
#    {'appid': 1234630, 'name': 'Enemy Gates Stealth War'},
#    {'appid': 1234680, 'name': 'Volatile'},
#    {'appid': 1234690, 'name': 'Gotcha'},
#    {'appid': 1234730, 'name': 'HereSphere'},
#    {'appid': 1234740, 'name': 'Efflorescence of Lust DLC18'},
#    {'appid': 1234750, 'name': "PENGUIN's DOGMA"},
#    {'appid': 1234760, 'name': 'The shameless squadron Pink woman'},
#    {'appid': 1234780,
#     'name': 'X-Plane 11 - Add-on: Aerosoft - Airport Chania - Ioannis Daskalogiannis'},
#    {'appid': 1234820, 'name': 'Mistaker'},
#    {'appid': 1234830, 'name': 'Warmth'},
#    {'appid': 1234840, 'name': 'Bone Marrow'},
#    {'appid': 1234850, 'name': 'Synthetic blood: Mind Shift'},
#    {'appid': 1234870, 'name': 'PsyHotel'},
#    {'appid': 1234890, 'name': 'Sokpop S07: labyrinth'},
#    {'appid': 1234900, 'name': 'Sheptun'},
#    {'appid': 1234930, 'name': 'Reach'},
#    {'appid': 1234940, 'name': 'Astronarch'},
#    {'appid': 1234950, 'name': 'Hunt: Showdown - Soundtrack'},
#    {'appid': 1234960, 'name': 'Greed'},
#    {'appid': 1234970, 'name': 'HOLMGANG: Memories of the Forgotten'},
#    {'appid': 1234980, 'name': 'Live To Win'},
#    {'appid': 1235060, 'name': 'Hentai Honeys Jigsaw - Geisya'},
#    {'appid': 1235070, 'name': 'The Explorer Demo'},
#    {'appid': 1235080, 'name': 'Hentai Honeys Jigsaw - Wife'},
#    {'appid': 1235100, 'name': 'Rolling Hills: Make Sushi, Make Friends'},
#    {'appid': 1234150,
#     'name': 'Super Jigsaw Puzzle: Generations - Sweets Puzzles'},
#    {'appid': 1234160, 'name': 'NUMTATE'},
#    {'appid': 1234170, 'name': 'The Final Boss Soundtrack'},
#    {'appid': 1234180, 'name': 'Moons Of Darsalon'},
#    {'appid': 1234190, 'name': 'ANIME WAR — Modern Campaign'},
#    {'appid': 1234200, 'name': 'Super Thrustforce: Orbital Meat Police'},
#    {'appid': 1234210, 'name': 'Mokoko - Nudity Patch'},
#    {'appid': 1234220, 'name': 'Paper Pirates'},
#    {'appid': 1234230, 'name': 'Hazardous Space - Wallpapers'},
#    {'appid': 1234240, 'name': 'Last Farewell'},
#    {'appid': 1234260, 'name': 'Deadly Land'},
#    {'appid': 1234270, 'name': 'The Coma 2: Vicious Sisters DLC - Soundtrack'},
#    {'appid': 1234280, 'name': "Fighters' Glory"},
#    {'appid': 1234320, 'name': 'The Kingless Land'},
#    {'appid': 1234340, 'name': 'GlowyJump'},
#    {'appid': 1234380, 'name': 'Era of Survival'},
#    {'appid': 1234390, 'name': 'COLOR DEFENSE - SUPER IDLE PET'},
#    {'appid': 1234391, 'name': 'COLOR DEFENSE - SUPER ATTACK PET'},
#    {'appid': 1234392, 'name': 'COLOR DEFENSE - PREMIUM ACCOUNT'},
#    {'appid': 1234393, 'name': 'COLOR DEFENSE - ALL MAP UNLOCK'},
#    {'appid': 1234400, 'name': 'Handy Dandy'},
#    {'appid': 1234410, 'name': 'Valiant Gears'},
#    {'appid': 1234460, 'name': 'Bernadette and the Demon Circus'},
#    {'appid': 1234470,
#     'name': 'Yuhha: Stolen Treasure Demo (English language)'},
#    {'appid': 1234490, 'name': 'Max Gentlemen Sexy Business! Soundtrack'},
#    {'appid': 1234510, 'name': 'Aircraft War: Space Wars'},
#    {'appid': 1234520, 'name': 'The Escaper'},
#    {'appid': 1234540, 'name': 'Bob Wants to Go Home'},
#    {'appid': 1234550, 'name': 'Quest Rooms'},
#    {'appid': 1234570, 'name': 'Episode 1'},
#    {'appid': 1233720, 'name': 'The Parenting Simulator'},
#    {'appid': 1233810, 'name': 'Men Busters'},
#    {'appid': 1233820, 'name': 'A Ton Of Feathers'},
#    {'appid': 1233850, 'name': 'The Aegis Saga'},
#    {'appid': 1233860, 'name': 'The Aegis Saga Demo'},
#    {'appid': 1233900, 'name': 'Lustful Valley'},
#    {'appid': 1233950, 'name': 'Wayhaven Chronicles: Book Two'},
#    {'appid': 1233960, 'name': 'Wayhaven Chronicles: Book Two Demo'},
#    {'appid': 1233990, 'name': "Tinieblas Jr's Adventures"},
#    {'appid': 1234030, 'name': 'ゴシックマーダー -運命を変えるアドベンチャー-'},
#    {'appid': 1234060, 'name': '人血馒头'},
#    {'appid': 1234070, 'name': 'Wire Flying Maid'},
#    {'appid': 1233210, 'name': 'Hentai Honeys Jigsaw'},
#    {'appid': 1233220, 'name': 'Disco Elysium Soundtrack'},
#    {'appid': 1233230, 'name': 'You Are A Bird'},
#    {'appid': 1233240, 'name': '墨游记 Inkball adventures'},
#    {'appid': 1233250, 'name': 'Abracadabrew'},
#    {'appid': 1233260, 'name': 'FAIRY TAIL'},
#    {'appid': 1233270, 'name': 'OshiRabu: Waifus Over Husbandos'},
#    {'appid': 1233280,
#     'name': 'The Witcher 3: Wild Hunt - Hearts of Stone Soundtrack'},
#    {'appid': 1233290, 'name': 'Poisoner - DLC package'},
#    {'appid': 1233310,
#     'name': 'True Love ～Confide to the Maple～枫茜语音 Character Voice'},
#    {'appid': 1233320,
#     'name': 'True Love ～Confide to the Maple～海音语音 Character Voice'},
#    {'appid': 1233330, 'name': "Roman's Christmas / 罗曼圣诞探案集 Soundtrack"},
#    {'appid': 1233340,
#     'name': 'The Witcher 3: Wild Hunt - Blood and Wine Soundtrack'},
#    {'appid': 1233350, 'name': 'Random Heroes: Gold Edition'},
#    {'appid': 1233360, 'name': 'Panzer Corps 2: Generals Edition Upgrade'},
#    {'appid': 1233370, 'name': "War Thunder - USSR Beginner's Pack"},
#    {'appid': 1233371, 'name': "War Thunder - German Beginner's Pack"},
#    {'appid': 1233372, 'name': 'War Thunder - Huey Hog Pack'},
#    {'appid': 1233373, 'name': 'War Thunder - Haida Pack'},
#    {'appid': 1233390, 'name': 'Fragile Demo'},
#    {'appid': 1233420, 'name': 'Wanderlust: Transsiberian'},
#    {'appid': 1233490, 'name': 'Trysaria Demo'},
#    {'appid': 1233510, 'name': 'Juice Mania'},
#    {'appid': 1233520, 'name': 'SpaceGeon Demo'},
#    {'appid': 1233540, 'name': 'How Buddy’s parents met - jigsaw puzzle'},
#    {'appid': 1233560, 'name': 'Asterism Online'},
#    {'appid': 1233580, 'name': 'Smile'},
#    {'appid': 1233600, 'name': 'Corporated Robots Wars'},
#    {'appid': 1233640, 'name': 'Spirit of Glace'},
#    {'appid': 1233650, 'name': 'BELOW Vol. 2 - Soundtrack'},
#    {'appid': 1232740, 'name': 'Potion Commotion Soundtrack'},
#    {'appid': 1232750, 'name': 'Fury Unleashed Soundtrack'},
#    {'appid': 1232770, 'name': 'Robotics in VR - Three Robots Pack DLC'},
#    {'appid': 1232780, 'name': 'Murder by Numbers Soundtrack'},
#    {'appid': 1232800, 'name': 'Connection Haunted'},
#    {'appid': 1232830, 'name': 'BoyandBox'},
#    {'appid': 1232890, 'name': 'DumbBots'},
#    {'appid': 1232920, 'name': 'Parliament - Parlement'},
#    {'appid': 1232980, 'name': 'Alien 911 Prologue'},
#    {'appid': 1233020, 'name': 'Betrayal'},
#    {'appid': 1233030, 'name': 'Armorik the Viking: The Eight Conquests'},
#    {'appid': 1233050, 'name': 'The Essence Reaper Ritual - Backer Pack'},
#    {'appid': 1233062, 'name': 'Borderlands 3: Season Pass'},
#    {'appid': 1233090, 'name': 'Mommy - Artbook'},
#    {'appid': 1233100,
#     'name': 'Street Fighter V - Capcom Pro Tour: 2020 Premier Pass'},
#    {'appid': 1233120, 'name': 'Street Racing 2020'},
#    {'appid': 1233170, 'name': 'Utopia Colony'},
#    {'appid': 1233200,
#     'name': "Wanko of Marriage ~Welcome to The Dog's Tail!~"},
#    {'appid': 1232255, 'name': 'Borderlands 3: Toy Box Weapons Pack'},
#    {'appid': 1232260, 'name': 'Space Mega Force Man'},
#    {'appid': 1232290, 'name': 'Oasis'},
#    {'appid': 1232310, 'name': 'Bonfire'},
#    {'appid': 1232320, 'name': 'Ballistic Craft Soundtrack'},
#    {'appid': 1232330, 'name': 'Theyest Thou'},
#    {'appid': 1232340,
#     'name': 'Null & Peta -Invasion of the Queen Bug- Art Book'},
#    {'appid': 1232350,
#     'name': 'Null & Peta -Invasion of the Queen Bug- Soundtrack'},
#    {'appid': 1232370, 'name': '星星校园生活'},
#    {'appid': 1232380, 'name': 'A Wild Time Travelling Clone Dancing'},
#    {'appid': 1232390, 'name': 'Dezatopia Soundtrack'},
#    {'appid': 1232420, 'name': 'Atlantica Global'},
#    {'appid': 1232430, 'name': 'Counter Fight 4'},
#    {'appid': 1232450, 'name': '来上大学吧！'},
#    {'appid': 1232470, 'name': 'The Aloha Bakery'},
#    {'appid': 1232510, 'name': 'Teleporter: World of Gamers (Alpha)'},
#    {'appid': 1232520, 'name': 'Wish Original Soundtrack'},
#    {'appid': 1232530, 'name': 'Vrerience - Safe Space (Forest)'},
#    {'appid': 1232540,
#     'name': "X-Plane 11 - Add-on: JustAsia - CYYT - St. John's International Airport"},
#    {'appid': 1232550, 'name': "The Mermaid's Secret Remedy The Love Spell"},
#    {'appid': 1232590, 'name': 'Dreamgate'},
#    {'appid': 1232610, 'name': 'Panic Station VR'},
#    {'appid': 1232650, 'name': 'Goblin treasure'},
#    {'appid': 1232670, 'name': 'Mercenaries VR'},
#    {'appid': 1232690, 'name': 'Toy Robot Soundtrack'},
#    {'appid': 1247000, 'name': 'Lords Of The Fallen Soundtrack'},
#    {'appid': 1247010, 'name': 'Legend of Keepers - Supporter Pack'},
#    {'appid': 1247030, 'name': 'Perpetual Dream'},
#    {'appid': 1247040, 'name': 'Void Monsters 2: The Blight'},
#    {'appid': 1247070, 'name': 'Rascallz: Tiki Tiki'},
#    {'appid': 1247080, 'name': 'Biped: Prologue'},
#    {'appid': 1247090, 'name': 'Stormworks Dedicated Server'},
#    {'appid': 1247100, 'name': 'SpellMaster: The Saga'},
#    {'appid': 1247110, 'name': 'Chasing Light'},
#    {'appid': 1247120, 'name': 'Minion Masters - Zealous Inferno'},
#    {'appid': 1247130,
#     'name': 'War Thunder: Air Forces, Vol.1 (Original Game Soundtrack)'},
#    {'appid': 1247140,
#     'name': 'War Thunder: Ground Forces, Vol.1 (Original Game Soundtrack)'},
#    {'appid': 1247150,
#     'name': 'War Thunder: Naval Forces, Vol.1 (Original Game Soundtrack)'},
#    {'appid': 1247170, 'name': 'Alien Cat'},
#    {'appid': 1247190, 'name': 'Family Mysteries 2: Echoes of Tomorrow'},
#    {'appid': 1247250, 'name': 'Quick Trivia'},
#    {'appid': 1247270, 'name': 'Divinity: Original Sin 2 Soundtrack'},
#    {'appid': 1247280, 'name': 'GirLand Soundtrack'},
#    {'appid': 1247290, 'name': 'GameGuru MAX'},
#    {'appid': 1247320, 'name': 'talesshop puzzle 테일즈샵퍼즐 - 죽어버린 별의 넋두리 드씨'},
#    {'appid': 1247330, 'name': 'Exploring Paradise Island'},
#    {'appid': 1247370, 'name': 'Voter fatigue'},
#    {'appid': 1247380, 'name': 'Mossen Seikkailut Soundtrack'},
#    {'appid': 1247400, 'name': 'Red Zirion'},
#    {'appid': 1247480, 'name': 'Weapons Genius. Modern Guns'},
#    {'appid': 1247490, 'name': 'Cube Course'},
#    {'appid': 1246500, 'name': 'Stone Story RPG Soundtrack'},
#    {'appid': 1246520, 'name': 'Uno - Uno Flip Theme'},
#    {'appid': 1246530, 'name': 'Danger Gazers - Next Stop'},
#    {'appid': 1246550, 'name': 'Poly Duels Demo'},
#    {'appid': 1246590, 'name': 'BEAR, VODKA, STALINGRAD! 🐻 - BALALAIKA MODE'},
#    {'appid': 1246591, 'name': 'BEAR, VODKA, STALINGRAD! 🐻 - STALIN MODE'},
#    {'appid': 1246600, 'name': 'Feed The Horsebear'},
#    {'appid': 1246610,
#     'name': 'GIRLS BATTLEGROUNDS | 性感大逃杀 - character customization'},
#    {'appid': 1246640,
#     'name': 'Fantasy Grounds - Jans Token Pack 07 - Under the Dark 1'},
#    {'appid': 1246650, 'name': 'Réel Futur'},
#    {'appid': 1246660,
#     'name': "Fantasy Grounds - Jan's Token Pack 06 - Heroes 2"},
#    {'appid': 1246670,
#     'name': 'Fantasy Grounds - Jans Token Pack 05 - Aquatic Creatures'},
#    {'appid': 1246680, 'name': 'Two Worlds - The 3D Art Gallery'},
#    {'appid': 1246700, 'name': 'TaP2 - Capitaine Douchebag Non-Censuré'},
#    {'appid': 1246710, 'name': 'Hooplord'},
#    {'appid': 1246730, 'name': 'Anime Artist 2: Ultra Lewd Pack'},
#    {'appid': 1246740, 'name': 'Capsa - Fire & Lightning Patterns Pack'},
#    {'appid': 1246750, 'name': 'Anime Artist 2: The More, The Better Pack'},
#    {'appid': 1246760, 'name': 'Anime Artist 2 - 18+ Patch'},
#    {'appid': 1246780, 'name': 'Hentai: Memory leak II'},
#    {'appid': 1246810, 'name': 'Puzzle Tower - Underground'},
#    {'appid': 1246830, 'name': 'Hentai Girl Seek - Adult Movies Patch 18+'},
#    {'appid': 1246840,
#     'name': 'DYNASTY WARRIORS 9: Cao Cao "Reinhard Costume" / 曹操「ラインハルト風コスチューム」'},
#    {'appid': 1246841,
#     'name': 'DYNASTY WARRIORS 9: Xiahou Dun "Kircheis Costume" / 夏侯惇「キルヒアイス風コスチューム」'},
#    {'appid': 1246842,
#     'name': 'DYNASTY WARRIORS 9: Zhuge Liang "Yang Costume" / 諸葛亮「ヤン風コスチューム」'},
#    {'appid': 1246843,
#     'name': 'DYNASTY WARRIORS 9: Jiang Wei "Julian Costume" / 姜維「ユリアン風コスチューム」'},
#    {'appid': 1246890, 'name': 'RPG Maker MV - Heroine Character Generator 5'},
#    {'appid': 1246900,
#     'name': 'RPG Maker VX Ace - Modern + Outer Basic  VX Ace'},
#    {'appid': 1246910, 'name': 'Sixth Night - Extra CG Pack'},
#    {'appid': 1246920, 'name': 'Iris and the giant Demo'},
#    {'appid': 1246930, 'name': 'Encore Classic Card Games'},
#    {'appid': 1246950, 'name': 'Where in the World is Carmen Sandiego?'},
#    {'appid': 1246100, 'name': 'Nibiru: Prologue'},
#    {'appid': 1246110, 'name': 'True Survivor'},
#    {'appid': 1246120, 'name': 'NeonFlight'},
#    {'appid': 1246140, 'name': 'Cybernetica'},
#    {'appid': 1246200, 'name': 'Super Toxicboy'},
#    {'appid': 1246210, 'name': 'FOS - LEGEND SKINS#1'},
#    {'appid': 1246300, 'name': 'Galactic Rangers VR - Digital Artbook'},
#    {'appid': 1246310, 'name': 'FOS - OTHER UNIVERSE SKINS'},
#    {'appid': 1246320, 'name': 'Euler Wars'},
#    {'appid': 1246330, 'name': 'FOS - NIGHT MODE'},
#    {'appid': 1246370, 'name': 'Outbreak: The New Nightmare - Camera Effects'},
#    {'appid': 1246390, 'name': 'Another_World'},
#    {'appid': 1246400, 'name': 'Ideology in Friction Append'},
#    {'appid': 1246420, 'name': "Clown Nightmare, Satan's Joke"},
#    {'appid': 1246430, 'name': 'NUMTATE Demo'},
#    {'appid': 1246460, 'name': '去死吧蝙蝠'},
#    {'appid': 1245550, 'name': 'Zombie Defense Shelter'},
#    {'appid': 1245580, 'name': 'Rest House 2 - The Wizard'},
#    {'appid': 1245600, 'name': 'Obelisk'},
#    {'appid': 1245630, 'name': 'Virage Rally'},
#    {'appid': 1245660, 'name': 'Ballavita'},
#    {'appid': 1245670, 'name': 'Blackstone Academy for the Magical Arts'},
#    {'appid': 1245680, 'name': 'Blackstone Academy for the Magical Arts Demo'},
#    {'appid': 1245700,
#     'name': 'The Lost Legends of Redwall: Escape the Gloomer Soundtrack'},
#    {'appid': 1245710, 'name': 'PING REDUX Demo'},
#    {'appid': 1245730, 'name': 'Chuck Meowrris'},
#    {'appid': 1245810, 'name': 'BitVault'},
#    {'appid': 1245820, 'name': 'Life of a Mercenary'},
#    {'appid': 1245900, 'name': 'Comrade-in-Arms'},
#    {'appid': 1245910, 'name': 'Hentai Most Wanted'},
#    {'appid': 1245920, 'name': 'CyberBall'},
#    {'appid': 1245930, 'name': 'Flaming Friday Night'},
#    {'appid': 1245960, 'name': 'tale of rainbow 7'},
#    {'appid': 1245980, 'name': 'Forest monster'},
#    {'appid': 1246010, 'name': 'CATharsis Demo'},
#    {'appid': 1246020, 'name': 'NOeSIS-诉说谎言的记忆之物语'},
#    {'appid': 1246030, 'name': 'Graviteam Tactics: Grim of Death'},
#    {'appid': 1246031, 'name': 'Graviteam Tactics: Strong Point'},
#    {'appid': 1246040, 'name': 'KARA Accounting'},
#    {'appid': 1246050, 'name': 'My Ex is a Ghost'},
#    {'appid': 1246060, 'name': '三国梦之队'},
#    {'appid': 1245000, 'name': 'Poly Duels'},
#    {'appid': 1245020,
#     'name': 'Fantasy Grounds - Starfinder Society Scenario #1-06: A Night in Nightarch'},
#    {'appid': 1245030, 'name': 'Hentai Seek Girl - Sexy Patch'},
#    {'appid': 1245050,
#     'name': 'Fantasy Grounds - Jans Token Pack 13 - Orc Horde'},
#    {'appid': 1245060, 'name': 'Somny & Yawn: Dream Detectives'},
#    {'appid': 1245070,
#     'name': 'Fantasy Grounds - Jans Token Pack 08 - Under the Dark 2'},
#    {'appid': 1245090, 'name': 'Teacher Lady'},
#    {'appid': 1245110, 'name': 'SimAirport - Frequent Flyer Pack'},
#    {'appid': 1245120, 'name': 'SteamVR - Half-Life: Alyx Environment'},
#    {'appid': 1245150, 'name': 'Remnant: From the Ashes - Swamps of Corsus'},
#    {'appid': 1245180, 'name': 'Marco & The Galaxy Dragon - Soundtrack'},
#    {'appid': 1245190,
#     'name': 'Marco & The Galaxy Dragon - Animation Soundtrack'},
#    {'appid': 1245200, 'name': 'Marco & The Galaxy Dragon - Luxury Art Book'},
#    {'appid': 1245220, 'name': 'Serial Lover'},
#    {'appid': 1245230, 'name': '地城蔷薇'},
#    {'appid': 1245260, 'name': 'Battle for Iwo Jima'},
#    {'appid': 1245280, 'name': 'Skeleton Warrior'},
#    {'appid': 1245300, 'name': 'Total Madness'},
#    {'appid': 1245310, 'name': 'GUN LADY Soundtrack'},
#    {'appid': 1245320, 'name': 'GUN LADY - Artbook 18+'},
#    {'appid': 1245330, 'name': 'Teacher Lady Soundtrack'},
#    {'appid': 1245340, 'name': 'Teacher Lady - Artbook 18+'},
#    {'appid': 1245350, 'name': 'Race Maniacs'},
#    {'appid': 1245360, 'name': 'Cubic Juice'},
#    {'appid': 1245370, 'name': 'Puzzle Forge Dungeon'},
#    {'appid': 1245380, 'name': 'NEKO-GIRL PLAY'},
#    {'appid': 1245390, 'name': 'Deep The Game - Cosmetics Expansion Pack'},
#    {'appid': 1245400, 'name': 'STATIONflow Original Soundtrack'},
#    {'appid': 1245430, 'name': 'Golden Light'},
#    {'appid': 1245470, 'name': 'Ultimate Ski Jumping 2020'},
#    {'appid': 1245500, 'name': 'Break the Web'},
#    {'appid': 1245510, 'name': "'Moskva' Paintings Pack"},
#    {'appid': 1244540, 'name': 'HENTAI DANCE Demo'},
#    {'appid': 1244550, 'name': 'HENTAI DANCE Soundtrack'},
#    {'appid': 1244560, 'name': 'Outward Soundtrack'},
#    {'appid': 1244600, 'name': 'Let`s Drive'},
#    {'appid': 1244620, 'name': 'PsychoSimulator'},
#    {'appid': 1244690, 'name': 'Buried Chambers'},
#    {'appid': 1244700,
#     'name': 'Super Jigsaw Puzzle: Generations - Australia Puzzles'},
#    {'appid': 1244710, 'name': 'Karate Cat Soundtrack'},
#    {'appid': 1244750, 'name': 'SpartrackVR-Firo Demo'},
#    {'appid': 1244760, 'name': '美少女格斗学院／Beautiful Girl Fight School'},
#    {'appid': 1244770, 'name': 'LilyDeux 警告の黒き百合'},
#    {'appid': 1244820, 'name': 'Gericonia 2 Demo'},
#    {'appid': 1244840,
#     'name': 'The Incredible Adventures of Van Helsing Soundtrack'},
#    {'appid': 1244850, 'name': 'Witch College 2'},
#    {'appid': 1244860, 'name': 'Dawn of Fear'},
#    {'appid': 1244870,
#     'name': 'Fantasy Grounds - Starfinder RPG - Starfinder Society Scenario #1-02: Fugitive on the Red Planet'},
#    {'appid': 1244880,
#     'name': 'Lethal League Blaze - Late Stage Illmatic outfit for Dice'},
#    {'appid': 1244890, 'name': 'Sunburnt'},
#    {'appid': 1244900,
#     'name': 'Fantasy Grounds - Starfinder RPG - Starfinder Society Scenario #1-01: The Commencement'},
#    {'appid': 1244920,
#     'name': "Fantasy Grounds - Pathfinder RPG - Adventurer's Guide"},
#    {'appid': 1244930, 'name': 'Mask of the Plague Doctor'},
#    {'appid': 1244940, 'name': 'Mask of the Plague Doctor Demo'},
#    {'appid': 1244960, 'name': 'Moonlight Mansion'},
#    {'appid': 1243980, 'name': 'My Company And I Fell Into An RPG'},
#    {'appid': 1243990, 'name': 'My Company And I Fell Into An RPG Demo'},
#    {'appid': 1244020, 'name': 'Lumin Demo'},
#    {'appid': 1244040, 'name': 'Crocotile 3D'},
#    {'appid': 1244050, 'name': 'Realm Hacker'},
#    {'appid': 1244080, 'name': 'Clipped Soundtrack'},
#    {'appid': 1244090, 'name': 'Project Solstice'},
#    {'appid': 1244160, 'name': 'Oxygen Not Included Soundtrack'},
#    {'appid': 1244180, 'name': 'Lovers Orcane Skin'},
#    {'appid': 1244190, 'name': 'Maze Burrow'},
#    {'appid': 1244210, 'name': 'Fragile Box'},
#    {'appid': 1244230, 'name': 'Rustissimo PRO'},
#    {'appid': 1244250,
#     'name': 'Hypergalactic Psychic Table Tennis 3000 Soundtrack'},
#    {'appid': 1244270, 'name': 'RimWorld - Royalty Soundtrack'},
#    {'appid': 1244300, 'name': 'The Astro Parcel Service'},
#    {'appid': 1244310, 'name': 'Wasteland Remastered Soundtrack'},
#    {'appid': 1244320, 'name': 'Honor Hill'},
#    {'appid': 1244370, 'name': 'Electronic Squash'},
#    {'appid': 1244390, 'name': 'My Little Cloud'},
#    {'appid': 1244410, 'name': 'Cloud Miners'},
#    {'appid': 1244440, 'name': 'Honey Dance'},
#    {'appid': 1244450, 'name': 'MoghVR'},
#    {'appid': 1244470, 'name': 'OneJump'},
#    {'appid': 1244490, 'name': 'Maiden and Swordsman - 18+ Adult Only Content'},
#    {'appid': 1243560, 'name': 'Vaporwave World'},
#    {'appid': 1243570,
#     'name': 'Tobari and the Night of the Curious Moon Soundtrack'},
#    {'appid': 1243640, 'name': 'Entelechy'},
#    {'appid': 1243670,
#     'name': 'Higurashi When They Cry Hou - Ch.8 Matsuribayashi'},
#    {'appid': 1243680,
#     'name': 'Super Jigsaw Puzzle: Generations - Boats Puzzles'},
#    {'appid': 1243681,
#     'name': 'Super Jigsaw Puzzle: Generations - Dogs Puzzles'},
#    {'appid': 1243682,
#     'name': 'Super Jigsaw Puzzle: Generations - Flowers Puzzles'},
#    {'appid': 1243710, 'name': 'Sigma Theory - Nigeria update'},
#    {'appid': 1243730, 'name': 'Four Ways'},
#    {'appid': 1243750, 'name': 'Sea Fishing Simulator'},
#    {'appid': 1243770,
#     'name': 'Holdfast: Nations At War - Loyalist Edition Upgrade'},
#    {'appid': 1243790, 'name': 'Heart Star'},
#    {'appid': 1243800, 'name': 'MindSeize Soundtrack'},
#    {'appid': 1243840,
#     'name': 'Nations At War Digital - White Star Rising Battle Pack 1'},
#    {'appid': 1243841,
#     'name': 'Nations At War Digital - White Star Rising Battle Pack 2'},
#    {'appid': 1243860, 'name': 'Resolutiion Demo'},
#    {'appid': 1243890, 'name': 'Sword of the Necromancer'},
#    {'appid': 1243930, 'name': 'Clipped'},
#    {'appid': 1243960, 'name': 'Unspottable'},
#    {'appid': 1242990, 'name': 'Goblin treasure Demo'},
#    {'appid': 1243000, 'name': 'KUNAI - OST'},
#    {'appid': 1243010,
#     'name': 'James Peris: Sin licencia ni control - Edición definitiva'},
#    {'appid': 1243020, 'name': "War Thunder - British Beginner's Pack"},
#    {'appid': 1243021, 'name': "War Thunder - Japanese Beginner's Pack"},
#    {'appid': 1243030, 'name': 'Send them to the sky'},
#    {'appid': 1243040, 'name': 'Pixel Pileup Party'},
#    {'appid': 1243050, 'name': 'Ostrova Koshki'},
#    {'appid': 1243060, 'name': 'Infiniball'},
#    {'appid': 1243080, 'name': 'Mini Hentai Puzzles'},
#    {'appid': 1243090, 'name': 'Hentai Girls Mosaic Puzzles'},
#    {'appid': 1243130, 'name': 'Nimbatus - Drone Creator'},
#    {'appid': 1243150, 'name': 'Bob Venture 3D Level Editor'},
#    {'appid': 1243190, 'name': 'HyperParasite Soundtrack'},
#    {'appid': 1243240, 'name': 'Season Match 4'},
#    {'appid': 1243260, 'name': 'Mossen Seikkailut'},
#    {'appid': 1243270, 'name': 'Castle of Lust - Hentai Fantasy Game'},
#    {'appid': 1243320, 'name': 'War for Magincia'},
#    {'appid': 1243330, 'name': 'War for Magincia Demo'},
#    {'appid': 1243380, 'name': 'Fantasy Grounds - For the Love of Valentine'},
#    {'appid': 1243390, 'name': 'IDLE WARRIOR - AUTO GOLD MINER'},
#    {'appid': 1243400, 'name': 'FireTry: Cars Pack'},
#    {'appid': 1243410, 'name': 'The Adventures of Spunk Dodgers and Splat'},
#    {'appid': 1243450,
#     'name': "Detectives United III: Timeless Voyage Collector's Edition"},
#    {'appid': 1243520, 'name': 'KUR'},
#    {'appid': 1242750,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Coral Pukei Strap'},
#    {'appid': 1242751,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Swinging Rajang'},
#    {'appid': 1242752,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Swinging Furious Rajang'},
#    {'appid': 1242753,
#     'name': "Monster Hunter World: Iceborne - Pendant: Strollin' Paolumu"},
#    {'appid': 1242754,
#     'name': "Monster Hunter World: Iceborne - Pendant: Strollin' Nightshade"},
#    {'appid': 1242755,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Flying Meduso'},
#    {'appid': 1242756,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Flying Meduso Colony'},
#    {'appid': 1242757,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Red Balloon'},
#    {'appid': 1242758,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Red & White Balloons'},
#    {'appid': 1242759,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Rainbow Balloons'},
#    {'appid': 1242760,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Room Decor: Splendid Decor Set'},
#    {'appid': 1242761,
#     'name': "Monster Hunter World: Iceborne - MHW:I Room Decor: Lil' Bit of Glamour Decor Set"},
#    {'appid': 1242762,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Room Decor: Mini Model Set'},
#    {'appid': 1242763,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Zinogre'},
#    {'appid': 1242764,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Yian Garuga'},
#    {'appid': 1242765,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Girros & Great Girros'},
#    {'appid': 1242766,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Namielle'},
#    {'appid': 1242767,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Paolumu'},
#    {'appid': 1242768,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Tzitzi-Ya-Ku'},
#    {'appid': 1242769,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Jyuratodus'},
#    {'appid': 1242770,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Barroth'},
#    {'appid': 1242771,
#     'name': 'Monster Hunter World: Iceborne - MHW:I Monster Figure: Diablos'},
#    {'appid': 1242790, 'name': 'The Crimson Diamond: Chapter 1'},
#    {'appid': 1242800, 'name': 'Tower of the Approval'},
#    {'appid': 1242810, 'name': 'Tower of the Approval Soundtrack'},
#    {'appid': 1242820, 'name': 'GirLand'},
#    {'appid': 1242840, 'name': 'French for 3D Visual Novel Maker'},
#    {'appid': 1242850, 'name': 'Movavi Slideshow Maker'},
#    {'appid': 1242910, 'name': 'The House in the Forest'},
#    {'appid': 1242920, 'name': 'The End of an Actress - Original Soundtrack'},
#    {'appid': 1242960, 'name': 'GUN LADY'},
#    {'appid': 1242970, 'name': 'SUPERVERSE Soundtrack'},
#    {'appid': 1242980, 'name': 'KeyWe'},
#    {'appid': 1241670, 'name': 'Swiper'},
#    {'appid': 1241680, 'name': 'Lucid Nina Demo'},
#    {'appid': 1241690, 'name': 'Fatal Wings'},
#    {'appid': 1241700, 'name': 'There is no game : Jam Edition 2015'},
#    {'appid': 1241740, 'name': 'ENDURE'},
#    {'appid': 1241760, 'name': 'Black Cat Adventures'},
#    {'appid': 1241780, 'name': 'CatDog Puzzle'},
#    {'appid': 1241810, 'name': 'Bowmen'},
#    {'appid': 1241820, 'name': 'Soul Axiom Rebooted Soundtrack'},
#    {'appid': 1241830, 'name': 'Mokoko Soundtrack'},
#    {'appid': 1241850,
#     'name': "Tony Stewart's Sprint Car Racing Pack 1 (Unlock_Pack1)"},
#    {'appid': 1241860, 'name': 'Get Good by Vypur'},
#    {'appid': 1241880, 'name': 'Swords and Sandals Official Soundtrack'},
#    {'appid': 1241920, 'name': 'Black Cat Adventures Demo'},
#    {'appid': 1241950, 'name': 'Warzone 2100'},
#    {'appid': 1242620, 'name': 'HUNGRY TEA PARTY'},
#    {'appid': 1242630, 'name': 'Skid Cities'},
#    {'appid': 1242650, 'name': "Desolate City's Destructive Soundtrack"},
#    {'appid': 1242670, 'name': 'RollingSky'},
#    {'appid': 1242690, 'name': 'HENTAI SEEK / Nude mode'},
#    {'appid': 1242700, 'name': '墲人之境：探索'},
#    {'appid': 1242710, 'name': 'Simplode Suite'},
#    {'appid': 1242730, 'name': '不要停下来啊！'},
#    {'appid': 1242740,
#     'name': "Monster Hunter: World - The Handler's Rose Vestido"},
#    {'appid': 1242741,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: Commander'},
#    {'appid': 1242742,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: Excitable A-Lister'},
#    {'appid': 1242743,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: Analytics Director'},
#    {'appid': 1242744,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: The Seeker'},
#    {'appid': 1242745,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: Serious Handler'},
#    {'appid': 1242746,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: Third Fleet Master'},
#    {'appid': 1242747,
#     'name': 'Monster Hunter World: Iceborne - Hairstyle: The Tracker'},
#    {'appid': 1242748,
#     'name': 'Monster Hunter: World - Sticker Set: Friendly Greetings Set'},
#    {'appid': 1242749,
#     'name': 'Monster Hunter World: Iceborne - Pendant: Pukei Strap'},
#    {'appid': 1276524, 'name': 'Bloons Monkey City - MC Darts Pack'},
#    {'appid': 1276525, 'name': 'Bloons Monkey City - Frontier Pack'},
#    {'appid': 1276530, 'name': 'Mr. Paf'},
#    {'appid': 1276560, 'name': 'Achievement Collector: Dog Soundtrack'},
#    {'appid': 1276580, 'name': 'Have You Washed Your Hands'},
#    {'appid': 1276600,
#     'name': 'The Chronicles of Robin Hood - The King of Thieves'},
#    {'appid': 1276610, 'name': 'My Cute Roommate'},
#    {'appid': 1276630, 'name': 'Doggy - Expansion Pack'},
#    {'appid': 1276650, 'name': 'Commercial License'},
#    {'appid': 1276720, 'name': 'Witching Tower: Heroes'},
#    {'appid': 1276770, 'name': 'Fantasy Memory Card Game - Expansion Pack 11'},
#    {'appid': 1276780, 'name': 'Tidal Shock: SURFERS DLC'},
#    {'appid': 1276781, 'name': 'Tidal Shock: DIVE CREW DLC'},
#    {'appid': 1276810, 'name': 'The Outbound Ghost'},
#    {'appid': 1276830, 'name': 'Project Speed - Expansion Pack #1'},
#    {'appid': 1276860, 'name': 'Mushroom Cats 2 Demo'},
#    {'appid': 1276890, 'name': 'The Lilliputian Runner'},
#    {'appid': 1277100, 'name': 'Dungeon & Derision'},
#    {'appid': 1277130, 'name': 'Deathbound'},
#    {'appid': 1277140, 'name': 'Underwater Wars'},
#    {'appid': 1276110, 'name': 'Crumbling World Demo'},
#    {'appid': 1276140, 'name': '核能步枪 '},
#    {'appid': 1276170, 'name': 'Pandemic Panic!'},
#    {'appid': 1276180, 'name': 'Inside Explorer'},
#    {'appid': 1276290, 'name': 'PST VR (Primary Surgical Treatment)'},
#    {'appid': 1276300, 'name': 'Zerowood'},
#    {'appid': 1276350, 'name': 'evolution for beginners'},
#    {'appid': 1276370, 'name': 'Elva the Eco Dragon'},
#    {'appid': 1276420, 'name': 'Hentai Honeys Jigsaw - Wife2'},
#    {'appid': 1276440, 'name': 'Monster surprised you-ki chan Demo'},
#    {'appid': 1276450, 'name': 'Modest Hero'},
#    {'appid': 1276480, 'name': '武动苍穹'},
#    {'appid': 1276500, 'name': 'Bloons Monkey City - Bamboo City Walls'},
#    {'appid': 1276501, 'name': 'Bloons Monkey City - Brick City Walls'},
#    {'appid': 1276502, 'name': 'Bloons Monkey City - Castle City Walls'},
#    {'appid': 1276503, 'name': 'Bloons Monkey City - Gold Path'},
#    {'appid': 1276510, 'name': 'Human Farm'},
#    {'appid': 1276520, 'name': 'Bloons Monkey City - Log City Walls'},
#    {'appid': 1276521, 'name': 'Bloons Monkey City - Sci-Fi City Walls'},
#    {'appid': 1276522, 'name': 'Bloons Monkey City - Eiffel Tower Pack'},
#    {'appid': 1276523, 'name': 'Bloons Monkey City - MOAB Madness Pack'},
#    {'appid': 1275640, 'name': 'Coloring Game 3'},
#    {'appid': 1275650, 'name': 'Mini Railway'},
#    {'appid': 1275730, 'name': ':THE LONGING: Soundtrack'},
#    {'appid': 1275780, 'name': 'Fantasy Memory Card Game - Expansion Pack 10'},
#    {'appid': 1275790, 'name': 'Space Otter Charlie'},
#    {'appid': 1275860, 'name': 'Kick the VIRUS'},
#    {'appid': 1275880, 'name': 'Happy Birthday, Adolf!'},
#    {'appid': 1275900, 'name': 'Pirate Code Soundtrack'},
#    {'appid': 1275940, 'name': 'Vivre avec Ataxie'},
#    {'appid': 1275950, 'name': 'Down The Rabbit Hole - Original Soundtrack'},
#    {'appid': 1275960, 'name': 'Blured Angel'},
#    {'appid': 1275970, 'name': 'Digital Dungeon Tiles'},
#    {'appid': 1275980, 'name': 'Probe'},
#    {'appid': 1276010, 'name': 'X-OUT'},
#    {'appid': 1276030, 'name': 'Wurmenai: The Sound Of Wurroom + Art Book'},
#    {'appid': 1276040, 'name': 'Mini Words: Top Movies'},
#    {'appid': 1276050, 'name': 'Void Destroyer 2 Soundtrack'},
#    {'appid': 1276060,
#     'name': 'Fingertips  mountain  sea- paradise island（指尖山海-天堂岛）'},
#    {'appid': 1275100, 'name': 'Fantasy Memory Card Game - Expansion Pack 9'},
#    {'appid': 1275140, 'name': 'Naked Story Demo'},
#    {'appid': 1275180, 'name': 'Hunter X - Begin'},
#    {'appid': 1275190, 'name': 'Inside The Mirror'},
#    {'appid': 1275200, 'name': 'Straylight Demo'},
#    {'appid': 1275210, 'name': 'Cross Soul'},
#    {'appid': 1275260, 'name': 'This will not go well'},
#    {'appid': 1275290, 'name': 'Dream Catcher'},
#    {'appid': 1275300, 'name': '炽焰帝国:十字军东征'},
#    {'appid': 1275330, 'name': 'Viking Heroes'},
#    {'appid': 1275360,
#     'name': 'X-Plane 11 - Add-on: Skyline Simulations - KLGB - Long Beach Airport XP'},
#    {'appid': 1275380,
#     'name': 'Notruf 112 - Die Feuerwehr Simulation 2: Showroom'},
#    {'appid': 1275390, 'name': 'City Destructor'},
#    {'appid': 1275430, 'name': 'Panzer Corps 2: Field Marshal Edition Upgrade'},
#    {'appid': 1275520, 'name': 'Choco Pixel 4'},
#    {'appid': 1275530, 'name': 'DeadsideServer'},
#    {'appid': 1275540, 'name': 'Go Kart Run!'},
#    {'appid': 1274840, 'name': 'Escape from GULAG'},
#    {'appid': 1274910, 'name': 'Active Neurons 2'},
#    {'appid': 1274930, 'name': 'Planet 2000'},
#    {'appid': 1274950, 'name': "lil' Sherman Original Soundtrack"},
#    {'appid': 1274960, 'name': 'Game Overlay Pro'},
#    {'appid': 1275020, 'name': 'Cosmic Flow - Supporter Option'},
#    {'appid': 1275030, 'name': "The King's Magic"},
#    {'appid': 1275040, 'name': 'Wardrobe pack for 3D Visual Novel Maker'},
#    {'appid': 1275050, 'name': 'Props pack for 3D Visual Novel Maker'},
#    {'appid': 1274380, 'name': 'Etheldia Pepper'},
#    {'appid': 1274420, 'name': 'Sakura Girls'},
#    {'appid': 1274430, 'name': 'OhWhoIsDancing'},
#    {'appid': 1274450, 'name': 'Bear Party: Adventure'},
#    {'appid': 1274470, 'name': 'Heim'},
#    {'appid': 1274500, 'name': 'Sacrifice Your Friends Demo'},
#    {'appid': 1274530, 'name': 'Gorilla Guerrillas'},
#    {'appid': 1274540, 'name': 'Tomatenquark'},
#    {'appid': 1274550, 'name': 'Dragon Storm'},
#    {'appid': 1274570, 'name': 'The Watchers: Devour'},
#    {'appid': 1274630, 'name': 'So May It Be: A Witch Dating Simulator'},
#    {'appid': 1274640, 'name': 'Nightvision'},
#    {'appid': 1274660, 'name': 'State of Decay: Original Game Soundtrack'},
#    {'appid': 1274670, 'name': 'DYB'},
#    {'appid': 1274680, 'name': 'Pattern OST / Companion'},
#    {'appid': 1274690, 'name': 'Sayonara Electric'},
#    {'appid': 1274790, 'name': 'Sex with Devil Demo'},
#    {'appid': 1274800, 'name': 'Pancake Sailor'},
#    {'appid': 1273890, 'name': 'Bastard Little Zombie'},
#    {'appid': 1273910, 'name': '3DRPG Soundtrack'},
#    {'appid': 1273920, 'name': "Dark Romance: Ashville Collector's Edition"},
#    {'appid': 1273930, 'name': 'Hard Rock Pinball'},
#    {'appid': 1273940, 'name': 'Fight for love'},
#    {'appid': 1273960, 'name': 'Rainbows, toilets & unicorns - Influencerama'},
#    {'appid': 1273961,
#     'name': 'Rainbows, toilets & unicorns - Political Drama'},
#    {'appid': 1273962,
#     'name': 'Rainbows, toilets & unicorns - Outraged & offended'},
#    {'appid': 1273963,
#     'name': 'Rainbows, toilets & unicorns - Entertainment Corp.'},
#    {'appid': 1274050, 'name': 'Project Genesis Soundtrack'},
#    {'appid': 1274060, 'name': 'The Ball Adventure'},
#    {'appid': 1274120, 'name': 'Daybringer Demo'},
#    {'appid': 1274180, 'name': 'Tower Ships'},
#    {'appid': 1274210, 'name': 'The Song of the Fae'},
#    {'appid': 1274220, 'name': 'The Song of the Fae Demo'},
#    {'appid': 1274250, 'name': 'Fire for Effect'},
#    {'appid': 1274280, 'name': 'Blue Flame'},
#    {'appid': 1274300, 'name': 'Cyber Agent'},
#    {'appid': 1274310, 'name': '东方鬼神玉'},
#    {'appid': 1273380, 'name': 'Weapons Genius VR'},
#    {'appid': 1273460,
#     'name': 'Soul at Stake - "Bitter Sugar" the Twins\' outfit'},
#    {'appid': 1273490, 'name': 'Soul at Stake - "Outlaw" Jacob\'s outfit'},
#    {'appid': 1273530, 'name': 'Endless Savagery'},
#    {'appid': 1273540, 'name': 'Mail Mole'},
#    {'appid': 1273570, 'name': 'Four Rendezvous'},
#    {'appid': 1273600, 'name': 'SPACE TOW TRUCK'},
#    {'appid': 1273630,
#     'name': 'Zaccaria Pinball - Strike Deluxe Pinball Table'},
#    {'appid': 1273640, 'name': 'Bring You Home'},
#    {'appid': 1273700, 'name': 'Day and Night'},
#    {'appid': 1273780, 'name': 'Peekaboo Collection - 3 Tales of Horror'},
#    {'appid': 1273790, 'name': 'Empires and Tribes'},
#    {'appid': 1273800, 'name': 'Vaccine'},
#    {'appid': 1273820, 'name': 'MicroMan'},
#    {'appid': 1273850, 'name': 'Koala Kids Soundtrack'},
#    {'appid': 1273860, 'name': 'Fantasy Memory Card Game - Expansion Pack 8'},
#    {'appid': 1273870, 'name': 'TechieChickVR'},
#    {'appid': 1273880, 'name': 'Human Universe Demo'},
#    {'appid': 1272970, 'name': 'Nyanco Card'},
#    {'appid': 1273000, 'name': 'Taravana: Hungry Sea Monsters'},
#    {'appid': 1273010, 'name': 'ASTRALODE Freeminers'},
#    {'appid': 1273020, 'name': 'Dark Side'},
#    {'appid': 1273030, 'name': 'Oh No! Bugs! Soundtrack'},
#    {'appid': 1273040,
#     'name': 'Fantasy Grounds - Starfinder RPG - Attack of the Swarm! AP 6: The God-Host Ascends'},
#    {'appid': 1273060, 'name': 'Aliens Love Beefs'},
#    {'appid': 1273090,
#     'name': 'Fantasy Grounds - Starfinder RPG - Starfinder Society Scenario #2-16: A Scoured Home'},
#    {'appid': 1273120, 'name': 'Eira: Echoes of Adventure'},
#    {'appid': 1273140,
#     'name': 'Fantasy Grounds - Devin Night TP125: Animals 3'},
#    {'appid': 1273160, 'name': 'Fall Of The Mafia'},
#    {'appid': 1273170,
#     'name': 'Fantasy Grounds - Devin Night TP122: Wasteland Warriors 1'},
#    {'appid': 1273190, 'name': 'Witch Zoe - Art Pack'},
#    {'appid': 1273200, 'name': 'Human Resource Machine Soundtrack'},
#    {'appid': 1273220, 'name': 'Sphere: Flying Cities'},
#    {'appid': 1273270, 'name': 'Dingleberries'},
#    {'appid': 1273290, 'name': 'BlindBlade II'},
#    {'appid': 1273300, 'name': 'Strings Demo'},
#    {'appid': 1273320, 'name': 'Tentacle Manor'},
#    {'appid': 1272710, 'name': '唐门六道'},
#    ...]}}

# %%
#using 100 data to demonstrate the results as an example
## write a new text file
def get_steam_app_info():
    url = 'https://api.steampowered.com/ISteamApps/GetAppList/v2/'
    r = requests.get(url)
    dic_app_list = r.json()
    lst_app_id = [i.get('appid') for i in dic_app_list.get('applist').get('apps')]
    print('Total apps:', len(lst_app_id[:50]))

    total_count = len(lst_app_id[:50])
    current_count = 0
    show_work_status(0, total_count, current_count)

    path_app_detail_sample = 'test_api.txt' 
    with open(path_app_detail_sample, 'w') as f:
        for app_id in lst_app_id[:50]:
            url_app_detail = ('http://store.steampowered.com/api/appdetails?appids=%s') % (app_id)
            for i in range(3):
                try:
                    r = requests.get(url_app_detail)
                    result = r.json()
                    break
                except:
                    time.sleep(5)
                    pass
            f.write(json.dumps(result))
            f.write('\n')
            show_work_status(1, total_count, current_count)
            current_count += 1
            if current_count % 200 == 0:
                time.sleep(300)
            else:
                time.sleep(.5)



get_steam_app_info()
# Out:
# Total apps: 50
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %% [markdown]
# ## get time data users spend on games

# %%
path_user_id = 'steam_user_id.txt'
with open(path_user_id, 'rb') as f:
    lst_user_id = f.readlines()[:50]

# %%
def worker(lst_user_id_temp):
    dic_temp = {}
    for user_id in lst_user_id_temp:
        base_url = 'http://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/'
        params = {
            'key' : '6A5C427F975DE2307958C931D1E24752',
            'steamid' : user_id.strip(),
            'format' : 'json' }
        r = requests.get(base_url, params = params)
        user_inventory = r.json().get('response').get('games')
        dic_temp.update({user_id.strip():user_inventory})
        time.sleep(.5)
    return dic_temp

# %%
from multiprocessing import Pool
p = Pool(2)

total_count = len(lst_user_id)
current_count = 0
show_work_status(0, total_count, current_count)

dic_master = {}
for i in split_list(lst_user_id,10):
    lst_temp_dic = p.map(worker, split_list(i,5))
    for j in lst_temp_dic:
        dic_master.update(j)
    show_work_status(len(i), total_count, current_count)
    current_count += len(i)
    time.sleep(5)
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%

# %%
## write a new inventory data
with open('crawled_user_inventory.txt', 'w') as f:
    for user_id, user_inventory in list(dic_master.items()):
        f.write(json.dumps({str(user_id):user_inventory}))
        f.write('\n')

# %% [markdown]
# ### Compare the speed in multiprocessing and in serial

# %%
def worker(lst_app_id):
    dic_temp = {}
    for app_id in lst_app_id:
        url_app_detail = ('http://store.steampowered.com/api/appdetails?appids=%s') % (app_id)
        for i in range(3):
            try:
                r = requests.get(url_app_detail)
                result = r.json()
                break
            except:
                time.sleep(5)
                pass
        dic_temp.update(result)
        time.sleep(.5)
    return dic_temp

# %%
url = 'https://api.steampowered.com/ISteamApps/GetAppList/v2/'
r = requests.get(url)
dic_app_list = r.json()
lst_app_id = [i.get('appid') for i in dic_app_list.get('applist').get('apps')]
list_test_app_id = lst_app_id[:100]

# %%
start=time.time()

a = worker(list_test_app_id)
end = time.time()
print(end - start)
# Out:
# 124.43986821174622

# %%
from multiprocessing import Pool
start=time.time()
p = Pool(2)

total_count = len(list_test_app_id)
current_count = 0
show_work_status(0, total_count, current_count)
dic_master = {}
for i in split_list(list_test_app_id,10):
    lst_temp_dic = p.map(worker, split_list(i,5))
    for j in lst_temp_dic:
        dic_master.update(j) 
    show_work_status(len(i), total_count, current_count)
    current_count += len(i)

end = time.time()
print(end - start)
# Out:
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%
#
# 63.35708785057068

# %% [markdown]
# ## Parse data into dataframe

# %%
# set file path
path_app_info = 'app_detail.txt'
path_user_inventory = 'user_inventory.txt'

# %%
def parse_steam_app_info(steam_app_info):
    if steam_app_info:
        for app_id, app_info in steam_app_info.items():
            success = app_info.get('success')
            if success:
                success = 1
                app_data = app_info.get('data')
                developers = ', '.join(app_data.get('developers', []))
                if not developers:
                    developers = None
                publishers = ', '.join(app_data.get('publishers', []))
                if not publishers:
                    publishers = None
                name = app_data.get('name')
                required_age = app_data.get('required_age')
                short_description = app_data.get('short_description')
                critic_score = app_data.get('metacritic', {}).get('score')
                app_type = app_data.get('type')
                recommendation = app_data.get('recommendations',{}).get('total')
                header_image = app_data.get('header_image')
                fullgame = app_data.get('fullgame',{}).get('appid')
                supported_languages = app_data.get('supported_languages')
                if supported_languages:
                    supported_languages = supported_languages.replace('<strong>*</strong>', '').replace('<br>languages with full audio support','')
                if app_data.get('is_free') == True:
                    initial_price = 0
                    currency = 'USD'
                else:
                    if app_data.get('price_overview',{}):
                        initial_price = app_data.get('price_overview',{}).get('initial', 0) / 100
                        currency = app_data.get('price_overview',{}).get('currency')
                    else:
                        initial_price = None
                        currency = None
                if app_data.get('platforms',{}).get('linux'):
                    linux = 1
                else:
                    linux = 0
                if app_data.get('platforms',{}).get('mac'):
                    mac = 1
                else:
                    mac = 0
                if app_data.get('platforms',{}).get('windows'):
                    windows = 1
                else:
                    windows = 0
                if app_data.get('release_date',{}).get('coming_soon') == False:
                    release_date = app_data.get('release_date',{}).get('date')
                    if release_date:
                        try:
                            release_date = datetime.strptime(release_date, '%b %d, %Y').date()
                        except Exception as e:
                            try:
                                release_date = datetime.strptime(release_date, '%d %b, %Y').date()
                            except:
                                try:
                                    release_date = datetime.strptime(release_date, '%b %Y').date()
                                except:
                                    release_date = None
                    else:
                        release_date = None
                else:
                    release_date = None
                dic_steam_app = {
                    app_id : {
                        'app_id' : app_id,
                        'currency' : currency,
                        'developers' : developers,
                        'publishers' : publishers,
                        'name' : name,
                        'required_age' : required_age,
                        'short_description' : short_description,
                        'critic_score' : critic_score,
                        'type' : app_type,
                        'recommendation' : recommendation,
                        'header_image' : header_image,
                        'initial_price' : initial_price,
                        'linux' : linux,
                        'mac' : mac,
                        'windows' : windows,
                        'fullgame' : fullgame,
                        'release_date' : release_date,
                        'supported_languages' : supported_languages,
                        'success' : success
                    }
                }
            else:
                dic_steam_app = {app_id : {'app_id' : app_id, 'success' : 0}}
    else:
        dic_steam_app = {}
    return dic_steam_app

# %%
def update_steam_game_info():
    print('Parse app info and dump to database')
    dic_steam_app = {}
    with open(path_app_info, 'rb') as f:
        lst_raw_string = f.readlines()
        total_count = len(lst_raw_string)
        current_count = 0
        for i in lst_raw_string[:10]:
            app_info = json.loads(i)
            dic_steam_app.update(parse_steam_app_info(app_info))
            show_work_status(1, total_count, current_count)
            current_count += 1
            
    df_steam_app = pd.DataFrame.from_dict(dic_steam_app, 'index')
    df_steam_app = df_steam_app.loc[:,['app_id','name', 'release_date', 'type', 'currency', 'initial_price', 'developers', 'publishers', 'required_age', 'linux', 'mac', 'windows', 'fullgame', 'supported_languages', 'header_image', 'short_description']]
    ##df_steam_app.to_csv('app_info.csv')
    
    return dic_steam_app
update_steam_game_info()
# Out:
# Parse app info and dump to database
# [                                                                                                    ] 0.01%
# {'216938': {'app_id': '216938', 'success': 0},
#  '660010': {'app_id': '660010', 'success': 0},
#  '660130': {'app_id': '660130', 'success': 0},
#  '1011480': {'app_id': '1011480',
#   'currency': 'USD',
#   'developers': 'Esteran',
#   'publishers': "Olea's World",
#   'name': "Olea's Descent Amazing Pets",
#   'required_age': 0,
#   'short_description': "Pets for Olea's Descent. Collect and trade them with your friends.",
#   'critic_score': None,
#   'type': 'dlc',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011480/header.jpg?t=1547280459',
#   'initial_price': 0.99,
#   'linux': 0,
#   'mac': 0,
#   'windows': 1,
#   'fullgame': '986100',
#   'release_date': datetime.date(2019, 1, 11),
#   'supported_languages': 'English',
#   'success': 1},
#  '1011530': {'app_id': '1011530',
#   'currency': None,
#   'developers': 'Laxity Media',
#   'publishers': 'Laxity Media',
#   'name': 'Super Gerry',
#   'required_age': 0,
#   'short_description': "Laxity Media presents a wonderful Jump 'n Run game. You must help Gerry to find the exit portal of the music wonderland. Don't lose the violin or you will not be able to return. Collect all the note bubbles. Don't fall into the rift. Be aware of the Groupies ! GO GO GO !!!",
#   'critic_score': None,
#   'type': 'game',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011530/header.jpg?t=1547139772',
#   'initial_price': None,
#   'linux': 0,
#   'mac': 0,
#   'windows': 1,
#   'fullgame': None,
#   'release_date': None,
#   'supported_languages': 'English, German',
#   'success': 1},
#  '1011540': {'app_id': '1011540',
#   'currency': 'USD',
#   'developers': 'Salangan Games',
#   'publishers': None,
#   'name': 'Zeliria Sanctuary - extension pack',
#   'required_age': '18',
#   'short_description': 'Want more interesting arts?',
#   'critic_score': None,
#   'type': 'dlc',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011540/header.jpg?t=1547153310',
#   'initial_price': 0,
#   'linux': 1,
#   'mac': 1,
#   'windows': 1,
#   'fullgame': '855630',
#   'release_date': datetime.date(2019, 1, 10),
#   'supported_languages': 'English, Russian',
#   'success': 1},
#  '1011640': {'app_id': '1011640',
#   'currency': 'USD',
#   'developers': 'DNT Games',
#   'publishers': None,
#   'name': 'The Good Left The City',
#   'required_age': 0,
#   'short_description': '&quot;I certainly hope you believe in something... ...every Story has to have an end...” The Good Left The City: the short novel conclusion to Alix: A MONITOR Story.',
#   'critic_score': None,
#   'type': 'dlc',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011640/header.jpg?t=1547470707',
#   'initial_price': 0,
#   'linux': 1,
#   'mac': 1,
#   'windows': 1,
#   'fullgame': '672650',
#   'release_date': datetime.date(2019, 1, 14),
#   'supported_languages': 'English',
#   'success': 1},
#  '1011770': {'app_id': '1011770',
#   'currency': 'USD',
#   'developers': 'Dharker Studio',
#   'publishers': 'Dharker Studio',
#   'name': 'The Alchemist Demo',
#   'required_age': 0,
#   'short_description': 'Become an Alchemist; explore the Great Wilderness, fight monsters, find ingredients, craft potions &amp; items to sell in your shop, gain power to become a Master Alchemist in the fantasy world of Ethermearial.',
#   'critic_score': None,
#   'type': 'demo',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011770/header.jpg?t=1546984921',
#   'initial_price': 0,
#   'linux': 1,
#   'mac': 1,
#   'windows': 1,
#   'fullgame': '762000',
#   'release_date': None,
#   'supported_languages': 'English',
#   'success': 1},
#  '1011800': {'app_id': '1011800',
#   'currency': 'USD',
#   'developers': 'Choice of Games',
#   'publishers': 'Choice of Games',
#   'name': 'Chronicon Apocalyptica Demo',
#   'required_age': 0,
#   'short_description': 'Battle Norse raiders, ghosts, and changelings to save medieval England! But beware, if the elves can capture the Book you hold, the world will end.',
#   'critic_score': None,
#   'type': 'demo',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011800/header.jpg?t=1547231860',
#   'initial_price': 0,
#   'linux': 1,
#   'mac': 1,
#   'windows': 1,
#   'fullgame': '1001500',
#   'release_date': datetime.date(2019, 1, 11),
#   'supported_languages': 'English',
#   'success': 1},
#  '1011870': {'app_id': '1011870',
#   'currency': None,
#   'developers': 'XFGames',
#   'publishers': 'XFGames',
#   'name': '萌盟大冒险 Cute Adventure',
#   'required_age': 0,
#   'short_description': '萌盟大冒险 Cute Adventure，is a multiplayer shoot game。Players will control the vibrant young characters, bring their own weapons to travel around adventure, defeat evil forces, maintain justice.Games are casual shooting games, I believe you can have fun!',
#   'critic_score': None,
#   'type': 'game',
#   'recommendation': None,
#   'header_image': 'https://steamcdn-a.akamaihd.net/steam/apps/1011870/header.jpg?t=1547266850',
#   'initial_price': None,
#   'linux': 0,
#   'mac': 0,
#   'windows': 1,
#   'fullgame': None,
#   'release_date': None,
#   'supported_languages': 'English, Simplified Chinese',
#   'success': 1}}

# %%
def update_steam_game_info():
    print('Parse app info and dump to database')
    dic_steam_app = {}
    with open(path_app_info, 'rb') as f:
        lst_raw_string = f.readlines()
        total_count = len(lst_raw_string)
        current_count = 0
        for i in lst_raw_string:
            app_info = json.loads(i)
            dic_steam_app.update(parse_steam_app_info(app_info))
            show_work_status(1, total_count, current_count)
            current_count += 1
            
    df_steam_app = pd.DataFrame.from_dict(dic_steam_app, 'index')
    df_steam_app = df_steam_app.loc[:,['app_id','name', 'release_date', 'type', 'currency', 'initial_price', 'developers', 'publishers', 'required_age', 'linux', 'mac', 'windows', 'fullgame', 'supported_languages', 'header_image', 'short_description']]
    ##df_steam_app.to_csv('app_info.csv')
    print(df_steam_app.shape)
    
    return df_steam_app
update_steam_game_info()
# Out:
# Parse app info and dump to database
# [>>>>                                                                                                ] 4.09%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>                                                                                           ] 9.55%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>>>>>>>>>                                                                                   ] 17.18%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>                                                                        ] 28.72%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>                             ] 71.75%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>                     ] 79.39%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 100.00%
#
# (73413, 16)
#           app_id                         name release_date  type currency  \
# 216938    216938                          NaN          NaN   NaN      NaN
# 660010    660010                          NaN          NaN   NaN      NaN
# 660130    660130                          NaN          NaN   NaN      NaN
# 1011480  1011480  Olea's Descent Amazing Pets   2019-01-11   dlc      USD
# 1011530  1011530                  Super Gerry         None  game     None
# ...          ...                          ...          ...   ...      ...
# 895670    895670                      Armajet   2018-09-25  game      USD
# 755800    755800                  Hades' Star         None  game      USD
# 697340    697340                  Fairy Light         None  game     None
# 1003550  1003550         Search for Surf Demo         None  demo      USD
# 422510    422510                 DEMON'S TILT         None  game     None
#
#          initial_price           developers           publishers required_age  \
# 216938             NaN                  NaN                  NaN          NaN
# 660010             NaN                  NaN                  NaN          NaN
# 660130             NaN                  NaN                  NaN          NaN
# 1011480           0.99              Esteran         Olea's World            0
# 1011530            NaN         Laxity Media         Laxity Media            0
# ...                ...                  ...                  ...          ...
# 895670            0.00    Super Bit Machine    Super Bit Machine            0
# 755800            0.00   Parallel Space Inc   Parallel Space Inc            0
# 697340             NaN  Mistake Game Studio  Mistake Game Studio            0
# 1003550           0.00            Cuttinged            Cuttinged            0
# 422510             NaN   WIZNWAR, FLARB LLC            FLARB LLC            0
#
#          linux  mac  windows fullgame  \
# 216938     NaN  NaN      NaN      NaN
# 660010     NaN  NaN      NaN      NaN
# 660130     NaN  NaN      NaN      NaN
# 1011480    0.0  0.0      1.0   986100
# 1011530    0.0  0.0      1.0     None
# ...        ...  ...      ...      ...
# 895670     0.0  1.0      1.0     None
# 755800     0.0  1.0      1.0     None
# 697340     0.0  0.0      1.0     None
# 1003550    0.0  0.0      1.0   958220
# 422510     0.0  1.0      1.0     None
#
#                                        supported_languages  \
# 216938                                                 NaN
# 660010                                                 NaN
# 660130                                                 NaN
# 1011480                                            English
# 1011530                                    English, German
# ...                                                    ...
# 895670                                             English
# 755800   English, French, Italian, German, Spanish - Sp...
# 697340                                    English, Russian
# 1003550                                            English
# 422510   English, French, Italian, German, Spanish - Sp...
#
#                                               header_image  \
# 216938                                                 NaN
# 660010                                                 NaN
# 660130                                                 NaN
# 1011480  https://steamcdn-a.akamaihd.net/steam/apps/101...
# 1011530  https://steamcdn-a.akamaihd.net/steam/apps/101...
# ...                                                    ...
# 895670   https://steamcdn-a.akamaihd.net/steam/apps/895...
# 755800   https://steamcdn-a.akamaihd.net/steam/apps/755...
# 697340   https://steamcdn-a.akamaihd.net/steam/apps/697...
# 1003550  https://steamcdn-a.akamaihd.net/steam/apps/100...
# 422510   https://steamcdn-a.akamaihd.net/steam/apps/422...
#
#                                          short_description
# 216938                                                 NaN
# 660010                                                 NaN
# 660130                                                 NaN
# 1011480  Pets for Olea's Descent. Collect and trade the...
# 1011530  Laxity Media presents a wonderful Jump 'n Run ...
# ...                                                    ...
# 895670   Unique 2.5D multiplayer jetpack combat that un...
# 755800   A unique space strategy game where thousands o...
# 697340   Fairy Light renews the style and spirit of the...
# 1003550                     Physics based 3D surfing game.
# 422510   TURBO CHARGED PINBALL RETURNS! Now with bigger...
#
# [73413 rows x 16 columns]

# %%
lst_player_game_playtime = []        
with open(path_user_inventory, 'r') as f:
    for raw_string in f.readlines():
        for user_id, lst_inventory in list(json.loads(raw_string).items()):
            if lst_inventory:
                for i in lst_inventory:
                    lst_player_game_playtime.append((int(user_id),i['appid'],i['playtime_forever']))
                    
                    #show_work_status(1, total_count, current_count)
                    #current_count += 1

df_player_time = pd.DataFrame(lst_player_game_playtime,columns = ["steamid","appid","playtime_forever"])
##df_player_time.to_csv("steam_playertime.csv")
print(df_player_time.shape)
df_player_time.head()
# Out:
# (393362, 3)
#              steamid   appid  playtime_forever
# 0  76561198158086086    4000               370
# 1  76561198158086086  110800                 9
# 2  76561198158086086  226320                 0
# 3  76561198158086086  250320               507
# 4  76561198158086086  296470                78
